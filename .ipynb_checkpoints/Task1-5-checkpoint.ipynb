# %% [markdown]
# ### 2) import necessary libraries

# %%
from textblob import TextBlob
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import nltk
import nltk
import re
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')
from collections import Counter
sns.set()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Barb\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Barb\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Barb\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Barb\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\Barb\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!

# %% [markdown]
# ### 3) open 20th century text file that I scraped in Task #1.4

# %%
# Import txt file

with open('20th_Century_article_Wiki.txt', 'r', errors='ignore') as file: 
   data = file.read().replace( '\n', ' ')

# %%
# tokenize the text into sentences

# %% [markdown]
# ### 4) Tokenize the words from the text and create a bar chart to plot 10 most common words

# %%
# Word tokenization

from nltk.tokenize import word_tokenize      
tokenized_word = word_tokenize(data)           #tokenize text into single words using word_tokenize() function:
print(tokenized_word)
# Out:
# ['20th', 'century', '-', 'Wikipedia', 'Jump', 'to', 'content', 'Main', 'menu', 'Main', 'menu', 'move', 'to', 'sidebar', 'hide', 'Navigation', 'Main', 'pageContentsCurrent', 'eventsRandom', 'articleAbout', 'WikipediaContact', 'us', 'Contribute', 'HelpLearn', 'to', 'editCommunity', 'portalRecent', 'changesUpload', 'file', 'Search', 'Search', 'Appearance', 'Donate', 'Create', 'account', 'Log', 'in', 'Personal', 'tools', 'Donate', 'Create', 'account', 'Log', 'in', 'Pages', 'for', 'logged', 'out', 'editors', 'learn', 'more', 'ContributionsTalk', 'Contents', 'move', 'to', 'sidebar', 'hide', '(', 'Top', ')', '1', 'Summary', '2', 'Nature', 'of', 'innovation', 'and', 'change', '3', 'Social', 'change', '4', 'Earth', 'at', 'the', 'end', 'of', 'the', '20th', 'century', '5', 'Wars', 'and', 'politics', '6', 'Culture', 'and', 'entertainment', 'Toggle', 'Culture', 'and', 'entertainment', 'subsection', '6.1', 'Music', '6.2', 'Film', ',', 'television', 'and', 'theatre', '6.3', 'Video', 'games', '6.4', 'Art', 'and', 'architecture', '6.5', 'Sport', '7', 'Science', 'Toggle', 'Science', 'subsection', '7.1', 'Mathematics', '7.2', 'Physics', '7.3', 'Astronomy', '7.4', 'Agriculture', '7.5', 'Biology', '7.6', 'Medicine', '7.6.1', 'Notable', 'diseases', '7.7', 'Energy', 'and', 'the', 'environment', '8', 'Engineering', 'and', 'technology', 'Toggle', 'Engineering', 'and', 'technology', 'subsection', '8.1', 'Space', 'exploration', '9', 'Religion', '10', 'Economics', '11', 'See', 'also', '12', 'References', '13', 'Sources', '14', 'Further', 'reading', '15', 'External', 'links', 'Toggle', 'the', 'table', 'of', 'contents', '20th', 'century', '170', 'languages', 'AfrikaansAlemannischáŠ', 'áˆ›áˆ\xadáŠ›Ã†ngliscØ§Ù', '„', 'Ø¹Ø±Ø¨ÙŠØ©AragonÃ©sArpetanAsturianuÐÐ²Ð°Ñ€AzÉ™rbaycancaØªÛ†Ø±Ú©Ø¬Ù‡Basa', 'Balià¦¬à¦¾à¦‚à¦²à¦¾é–©å—èªž', '/', 'BÃ¢n-lÃ¢m-gÃºBasa', 'BanyumasanÐ', '‘', 'Ð°ÑˆÒ¡Ð¾Ñ€Ñ‚ÑÐ°Ð', '‘', 'ÐµÐ', '»', 'Ð°Ñ€ÑƒÑÐºÐ°ÑÐ', '‘', 'ÐµÐ', '»', 'Ð°Ñ€ÑƒÑÐºÐ°Ñ', '(', 'Ñ‚Ð°Ñ€Ð°ÑˆÐºÐµÐ²Ñ–Ñ†Ð°', ')', 'Ð', '‘', 'ÑŠÐ', '»', 'Ð³Ð°Ñ€ÑÐºÐ¸BosanskiBrezhonegÐ', '‘', 'ÑƒÑ€ÑÐ°Ð´CatalÃ', 'Ð§Ó', '‘', 'Ð²Ð°ÑˆÐ', '»', 'Ð°CebuanoÄŒeÅ¡tinaCymraegDanskØ§Ù', '„', 'Ø¯Ø§Ø±Ø¬Ø©DavvisÃ¡megiellaDeutschEestiÎ•Î', '»', 'Î', '»', 'Î·Î½Î¹ÎºÎ¬EmiliÃ', 'n', 'e', 'rumagnÃ²lÐ\xadÑ€Ð·ÑÐ½ÑŒEspaÃ±olEsperantoEstremeÃ±uEuskaraÙØ§Ø±Ø³ÛŒFiji', 'HindiFÃ¸roysktFranÃ§aisFryskGaeilgeGaelgGÃ', 'idhligGalegoÐ', '“', 'Ó€Ð°Ð', '»', 'Ð³Ó€Ð°Ð¹è´›èªžå®¢å®¶èªž', '/', 'Hak-kÃ¢-ngÃ®í•œêµ\xadì–´Õ€Õ¡ÕµÕ¥Ö€Õ¥Õ¶à¤¹à¤¿à¤¨à¥à¤¦à¥€HornjoserbsceHrvatskiIdoIlokanoBahasa', 'IndonesiaInterlinguaÐ˜Ñ€Ð¾Ð½ÃslenskaItaliano×¢×', '‘', '×¨×™×ªJawaáƒ¥áƒáƒ', 'áƒ—áƒ£áƒšáƒ˜ÒšÐ°Ð·Ð°Ò›ÑˆÐ°KernowekKiswahiliÐšÐ¾Ð¼Ð¸KotavaKurdÃ®àº¥àº²àº§LatgaÄ¼uLatinaLatvieÅ¡uLÃ', '«', 'tzebuergeschÐ›ÐµÐ·Ð³Ð¸LietuviÅ³LigureLimburgsLingÃ¡laLingua', 'Franca', 'NovaLivvinkarjalaLa', '.lojban.LombardMagyarÐœÐ°ÐºÐµÐ´Ð¾Ð½ÑÐºÐ¸à´®à´²à´¯à´¾à´³à´‚MÄorià¤®à¤°à¤¾à¤', 'à¥€áƒ›áƒáƒ', 'áƒ', '’', 'áƒáƒšáƒ£áƒ', 'áƒ˜Ù…ØµØ±Ù‰Ù…Ø§Ø²ÙØ±ÙˆÙ†ÛŒBahasa', 'Melayué–©æ±èªž', '/', 'MÃ¬ng-dÄ•Ì¤ng-ngá¹³Ì', '„', 'MirandÃ©sÐœÐ¾Ð½Ð³Ð¾Ð', '»', 'á€™á€¼á€', '”', 'á€ºá€™á€¬á€˜á€¬á€žá€¬NÄhuatlNederlandsNedersaksiesà¤¨à¥‡à¤ªà¤¾à¤²à¥€æ—¥æœ¬èªžNapulitanoÐÐ¾Ñ…Ñ‡Ð¸Ð¹Ð½NordfriiskNorsk', 'bokmÃ¥lNorsk', 'nynorskNouormandNovialOccitanÐžÐ', '»', 'Ñ‹Ðº', 'Ð¼Ð°Ñ€Ð¸Ð¹OÊ', '»', 'zbekcha', '/', 'ÑžÐ·Ð±ÐµÐºÑ‡Ð°à¨ªà©°à¨œà¨¾à¨¬à©€Ù¾Ù†Ø¬Ø§Ø¨ÛŒPapiamentuÙ¾ÚšØªÙˆPlattdÃ¼Ã¼tschPolskiPortuguÃªsRomÃ¢nÄƒRumantschRuna', 'SimiÐ', 'ÑƒÑÐ¸Ð½ÑŒÑÐºÑ‹Ð¹Ð', 'ÑƒÑÑÐºÐ¸Ð¹Ð¡Ð°Ñ…Ð°', 'Ñ‚Ñ‹Ð', '»', 'Ð°ScotsSeelterskSesotho', 'sa', 'LeboaShqipSicilianuà·ƒà·', '’', 'à¶‚à·', '„', 'à¶½Simple', 'EnglishSlovenÄinaSlovenÅ¡ÄinaÅšlÅ¯nskiSoomaaligaÚ©ÙˆØ±Ø¯ÛŒÐ¡Ñ€Ð¿ÑÐºÐ¸', '/', 'srpskiSrpskohrvatski', '/', 'ÑÑ€Ð¿ÑÐºÐ¾Ñ…Ñ€Ð²Ð°Ñ‚ÑÐºÐ¸SundaSuomiSvenskaTagalogà®¤à®®à®¿à®´à¯TaqbaylitÐ¢Ð°Ñ‚Ð°Ñ€Ñ‡Ð°', '/', 'tatarÃ§aá½á‚ƒá‚‡á€žá‚ƒá‚‡á€á‚†á€¸', 'à°¤à±†à°²à±à°—à±à¹', '„', 'à¸—à¸¢Ð¢Ð¾Ò·Ð¸ÐºÓ£TÃ¼rkÃ§eTÃ¼rkmenÃ§eÐ£ÐºÑ€Ð°Ñ—Ð½ÑÑŒÐºÐ°Ø§Ø±Ø¯ÙˆVÃ¨netoTiáº¿ng', 'Viá', '»', '‡tVolapÃ¼kVÃµroWalonWinarayå´è¯\xad×™×™Ö´×', '“', '×™×©ç²µèªžZazakiZeÃªuwsÅ½emaitÄ—Å¡kaä¸\xadæ–‡Tol ...

# %%
# Look at frequency distribution of most common words

# %%
from nltk.probability import FreqDist
dist_words = FreqDist(tokenized_word)
print(dist_words)
# Out:
# <FreqDist with 3565 samples and 12092 outcomes>

# %%
# Create a frequency distribution of 10 most common words

# %%
top10 = dist_words.most_common(10)

# %%
# Frequency Distribution Plot

plt.figure(figsize=(8, 3))
dist_words.plot(10,cumulative = False)
plt.show()

# %%
#Creating bar plot of 10 most common words

#plt.figure(figsize = (10, 5))
#with sns.dark_palette("xkcd:blue", 10):
#      sns.barplot(x = "Words", y = "Counts",
#    saturation = 0.9, data = top10).set_title("Key Events of 20th Century - top 10 words used")

# %% [markdown]
# ### 5a) Remove stop words (and punctuation marks if necessary).
# ### 5b) Then rerun plot

# %%
# Defining stopwords

from nltk.corpus import stopwords
stop_words = set(stopwords.words("english"))
print(stop_words)
# Out:
# {'them', 'with', 'shouldn', 'a', 'yourself', 'her', "aren't", "you're", 'itself', 'few', "doesn't", 'wouldn', 'are', 'and', 'weren', 'is', 'ain', 'ma', 'didn', 'of', 'am', 'shan', 'hasn', "she's", 'on', 'it', "should've", 'some', 'both', 'we', 'does', 'that', 'the', 'ourselves', 'only', 'doing', "wouldn't", 'for', 'me', 'its', 'his', 'your', 'hers', 'these', 'have', 'hadn', 'than', 'she', 'should', 'd', 'will', 't', 'further', 'can', "haven't", 'any', 'from', 'herself', 'o', 'myself', 'in', "you'll", "it's", "won't", "don't", 'theirs', 'but', 'into', 'll', "couldn't", 's', "hadn't", 'same', 'isn', 'not', 'do', 'above', 'until', 'such', 'won', "isn't", 'just', 'm', "mightn't", 'what', "wasn't", 'himself', 'wasn', 'themselves', "weren't", 'yourselves', 'haven', 'why', 'own', 'been', 'aren', 'once', 'other', 'while', "shan't", 'be', 'being', 'more', 'ours', 'don', 'no', 'so', 'which', 'as', 'nor', 'during', "didn't", "you'd", 'having', 'below', 'you', 'then', 'down', 've', 'him', 'to', 'through', 'were', "needn't", 'again', 'there', 'under', 'their', 'how', 'if', 'he', 'doesn', 'had', 'when', "mustn't", 'couldn', 'whom', 'who', 'this', 'before', "that'll", 'y', 'between', 'has', 'up', "hasn't", 'after', 'too', 'by', 'out', "shouldn't", 'all', 'off', 'now', 'because', 'our', 'was', 'did', 'my', 'here', 'yours', 'against', 'where', "you've", 'mustn', 'most', 'i', 'very', 'each', 're', 'needn', 'they', 'over', 'mightn', 'or', 'at', 'an', 'about', 'those'}

# %%
# Removing stop words
# stop words are simple words that convey no info
# Check if words in text are in stop word list (stop_words) of NLTK library

filtered_words = [] # creates an empty list
for word in tokenized_word:
      if word not in stop_words:
           filtered_words.append(word)

# %%
# Create a 2nd frequency distribution with stop words removed
# Create a new FreqDist of filtered–words

dist_words_filter = FreqDist(filtered_words)
print (dist_words_filter)
# Out:
# <FreqDist with 3478 samples and 9271 outcomes>

# %%
# Create bar plot of 10 common words with stop words removed
# Bar Plot of Frequency Distribution of filtered-words

plt.figure(figsize=(8, 3))
dist_words_filter.plot(10,cumulative = False)
plt.show()

# %% [markdown]
# After removing stopwords, the most common "words" were punctuation marks. The actual words dropped from 6 to 2.

# %%
# Remove common punctuation marks
# Substitute all punctuation marks with a space

sans_punc = re.sub("[^a-zA-Z]",  # Search for all non-letters
                        " ",        # Replace all non-letters with spaces
                        str(filtered_words))

# %%
# Tokenize text into single words without punctuation marks
# Word tokenization

tokenized_word_2 = word_tokenize(sans_punc)
print (tokenized_word_2)
# Out:
# ['th', 'century', 'Wikipedia', 'Jump', 'content', 'Main', 'menu', 'Main', 'menu', 'move', 'sidebar', 'hide', 'Navigation', 'Main', 'pageContentsCurrent', 'eventsRandom', 'articleAbout', 'WikipediaContact', 'us', 'Contribute', 'HelpLearn', 'editCommunity', 'portalRecent', 'changesUpload', 'file', 'Search', 'Search', 'Appearance', 'Donate', 'Create', 'account', 'Log', 'Personal', 'tools', 'Donate', 'Create', 'account', 'Log', 'Pages', 'logged', 'editors', 'learn', 'ContributionsTalk', 'Contents', 'move', 'sidebar', 'hide', 'Top', 'Summary', 'Nature', 'innovation', 'change', 'Social', 'change', 'Earth', 'end', 'th', 'century', 'Wars', 'politics', 'Culture', 'entertainment', 'Toggle', 'Culture', 'entertainment', 'subsection', 'Music', 'Film', 'television', 'theatre', 'Video', 'games', 'Art', 'architecture', 'Sport', 'Science', 'Toggle', 'Science', 'subsection', 'Mathematics', 'Physics', 'Astronomy', 'Agriculture', 'Biology', 'Medicine', 'Notable', 'diseases', 'Energy', 'environment', 'Engineering', 'technology', 'Toggle', 'Engineering', 'technology', 'subsection', 'Space', 'exploration', 'Religion', 'Economics', 'See', 'also', 'References', 'Sources', 'Further', 'reading', 'External', 'links', 'Toggle', 'table', 'contents', 'th', 'century', 'languages', 'AfrikaansAlemannisch', 'xad', 'nglisc', 'Aragon', 'sArpetanAsturianu', 'Az', 'rbaycanca', 'Basa', 'Bali', 'B', 'n', 'l', 'm', 'g', 'Basa', 'Banyumasan', 'BosanskiBrezhoneg', 'Catal', 'Cebuano', 'e', 'tinaCymraegDansk', 'Davvis', 'megiellaDeutschEesti', 'Emili', 'n', 'e', 'rumagn', 'l', 'xad', 'Espa', 'olEsperantoEstreme', 'uEuskara', 'Fiji', 'HindiF', 'roysktFran', 'aisFryskGaeilgeGaelgG', 'idhligGalego', 'Hak', 'k', 'ng', 'xad', 'HornjoserbsceHrvatskiIdoIlokanoBahasa', 'IndonesiaInterlingua', 'slenskaItaliano', 'Jawa', 'KernowekKiswahili', 'KotavaKurd', 'Latga', 'uLatinaLatvie', 'uL', 'tzebuergesch', 'Lietuvi', 'LigureLimburgsLing', 'laLingua', 'Franca', 'NovaLivvinkarjalaLa', 'lojban', 'LombardMagyar', 'M', 'ori', 'Bahasa', 'Melayu', 'M', 'ng', 'd', 'ng', 'ng', 'Mirand', 's', 'N', 'huatlNederlandsNedersaksies', 'Napulitano', 'NordfriiskNorsk', 'bokm', 'lNorsk', 'nynorskNouormandNovialOccitan', 'O', 'zbekcha', 'Papiamentu', 'Plattd', 'tschPolskiPortugu', 'sRom', 'n', 'RumantschRuna', 'Simi', 'ScotsSeelterskSesotho', 'sa', 'LeboaShqipSicilianu', 'Simple', 'EnglishSloven', 'inaSloven', 'ina', 'l', 'nskiSoomaaliga', 'srpskiSrpskohrvatski', 'SundaSuomiSvenskaTagalog', 'Taqbaylit', 'tatar', 'a', 'T', 'rk', 'eT', 'rkmen', 'e', 'V', 'netoTi', 'ng', 'Vi', 'tVolap', 'kV', 'roWalonWinaray', 'xad', 'ZazakiZe', 'uws', 'emait', 'ka', 'xad', 'Tol', 'i', 'Edit', 'links', 'ArticleTalk', 'English', 'ReadEditView', 'history', 'Tools', 'Tools', 'move', 'sidebar', 'hide', 'Actions', 'ReadEditView', 'history', 'General', 'What', 'links', 'hereRelated', 'changesUpload', 'fileSpecial', 'pagesPermanent', 'linkPage', 'informationCite', 'pageGet', 'shortened', 'URLDownload', 'QR', 'code', 'Print', 'export', 'Download', 'PDFPrintable', 'version', 'In', 'projects', 'Wikimedia', 'CommonsWikiquoteWikidata', 'item', 'Appearance', 'move', 'sidebar', 'hide', 'From', 'Wikipedia', 'free', 'encyclopedia', 'One', 'hundred', 'years', 'For', 'uses', 'see', 'th', 'century', 'disambiguation', 'Earthrise', 'taken', 'December', 'astronaut', 'William', 'Bill', 'Anders', 'Apollo', 'space', 'mission', 'It', 'first', 'photograph', 'taken', 'Earth', 'lunar', 'orbit', 'Millennium', 'nd', 'millennium', 'Centuries', 'th', 'century', 'th', 'century', 'st', 'century', 'Timelines', 'th', 'century', 'th', 'century', 'st', 'century', 'State', 'leaders', 'th', 'century', 'th', 'century', 'st', 'century', 'Decades', 's', 's', 's', 's', 's', 's', 's', 's', 's', 's', 'Categories', 'Births', 'Deaths', 'Establishments', 'Disestablishments', 'vteThe', 'th', 'century', 'began', 'January', 'MCMI', 'ended', 'December', 'MM', 'It', 'th', 'last', 'century', 'nd', 'millennium', 'marked', 'new', 'models', 'scientific', 'understanding', 'unprecedent ...

# %%
# Create a 3rd frequency distribution with punctuation marks removed from single words
# Create a new FreqDist

dist_words_filter_2 = FreqDist(tokenized_word_2)

# %%
# Create bar plot of single words with punctuation marks removed
# Bar Plot of Frequency Distribution of filtered-words

plt.figure(figsize=(8, 3))
dist_words_filter_2.plot(10,cumulative = False)
plt.show()

# %% [markdown]
# After removing stop words and punctuation marks, the 10 most common words are more meaningful.

# %%
# Remove a few more words and letters from list of single words w/o punctuation marks (tokenized_word_2)

# %%
new_stopwords = ["And", "Then", 'n', 't', 's', 'The']

filtered = []
for word in tokenized_word_2:
     if word not in new_stopwords:
        filtered.append(word)

# %% [markdown]
# ### 6) Create a tags list using TextBlob

# %%
    # Create TextBlob object - 1st thing to do when creating tags.

# %%
# %%time
text = TextBlob(str(filtered))
# Out:
# CPU times: total: 0 ns
# Wall time: 16.4 ms

# %%
text
# Out:
# TextBlob("['th', 'century', 'Wikipedia', 'Jump', 'content', 'Main', 'menu', 'Main', 'menu', 'move', 'sidebar', 'hide', 'Navigation', 'Main', 'pageContentsCurrent', 'eventsRandom', 'articleAbout', 'WikipediaContact', 'us', 'Contribute', 'HelpLearn', 'editCommunity', 'portalRecent', 'changesUpload', 'file', 'Search', 'Search', 'Appearance', 'Donate', 'Create', 'account', 'Log', 'Personal', 'tools', 'Donate', 'Create', 'account', 'Log', 'Pages', 'logged', 'editors', 'learn', 'ContributionsTalk', 'Contents', 'move', 'sidebar', 'hide', 'Top', 'Summary', 'Nature', 'innovation', 'change', 'Social', 'change', 'Earth', 'end', 'th', 'century', 'Wars', 'politics', 'Culture', 'entertainment', 'Toggle', 'Culture', 'entertainment', 'subsection', 'Music', 'Film', 'television', 'theatre', 'Video', 'games', 'Art', 'architecture', 'Sport', 'Science', 'Toggle', 'Science', 'subsection', 'Mathematics', 'Physics', 'Astronomy', 'Agriculture', 'Biology', 'Medicine', 'Notable', 'diseases', 'Energy', 'environment', 'Engineering', 'technology', 'Toggle', 'Engineering', 'technology', 'subsection', 'Space', 'exploration', 'Religion', 'Economics', 'See', 'also', 'References', 'Sources', 'Further', 'reading', 'External', 'links', 'Toggle', 'table', 'contents', 'th', 'century', 'languages', 'AfrikaansAlemannisch', 'xad', 'nglisc', 'Aragon', 'sArpetanAsturianu', 'Az', 'rbaycanca', 'Basa', 'Bali', 'B', 'l', 'm', 'g', 'Basa', 'Banyumasan', 'BosanskiBrezhoneg', 'Catal', 'Cebuano', 'e', 'tinaCymraegDansk', 'Davvis', 'megiellaDeutschEesti', 'Emili', 'e', 'rumagn', 'l', 'xad', 'Espa', 'olEsperantoEstreme', 'uEuskara', 'Fiji', 'HindiF', 'roysktFran', 'aisFryskGaeilgeGaelgG', 'idhligGalego', 'Hak', 'k', 'ng', 'xad', 'HornjoserbsceHrvatskiIdoIlokanoBahasa', 'IndonesiaInterlingua', 'slenskaItaliano', 'Jawa', 'KernowekKiswahili', 'KotavaKurd', 'Latga', 'uLatinaLatvie', 'uL', 'tzebuergesch', 'Lietuvi', 'LigureLimburgsLing', 'laLingua', 'Franca', 'NovaLivvinkarjalaLa', 'lojban', 'LombardMagyar', 'M', 'ori', 'Bahasa', 'Melayu', 'M', 'ng', 'd', 'ng', 'ng', 'Mirand', 'N', 'huatlNederlandsNedersaksies', 'Napulitano', 'NordfriiskNorsk', 'bokm', 'lNorsk', 'nynorskNouormandNovialOccitan', 'O', 'zbekcha', 'Papiamentu', 'Plattd', 'tschPolskiPortugu', 'sRom', 'RumantschRuna', 'Simi', 'ScotsSeelterskSesotho', 'sa', 'LeboaShqipSicilianu', 'Simple', 'EnglishSloven', 'inaSloven', 'ina', 'l', 'nskiSoomaaliga', 'srpskiSrpskohrvatski', 'SundaSuomiSvenskaTagalog', 'Taqbaylit', 'tatar', 'a', 'T', 'rk', 'eT', 'rkmen', 'e', 'V', 'netoTi', 'ng', 'Vi', 'tVolap', 'kV', 'roWalonWinaray', 'xad', 'ZazakiZe', 'uws', 'emait', 'ka', 'xad', 'Tol', 'i', 'Edit', 'links', 'ArticleTalk', 'English', 'ReadEditView', 'history', 'Tools', 'Tools', 'move', 'sidebar', 'hide', 'Actions', 'ReadEditView', 'history', 'General', 'What', 'links', 'hereRelated', 'changesUpload', 'fileSpecial', 'pagesPermanent', 'linkPage', 'informationCite', 'pageGet', 'shortened', 'URLDownload', 'QR', 'code', 'Print', 'export', 'Download', 'PDFPrintable', 'version', 'In', 'projects', 'Wikimedia', 'CommonsWikiquoteWikidata', 'item', 'Appearance', 'move', 'sidebar', 'hide', 'From', 'Wikipedia', 'free', 'encyclopedia', 'One', 'hundred', 'years', 'For', 'uses', 'see', 'th', 'century', 'disambiguation', 'Earthrise', 'taken', 'December', 'astronaut', 'William', 'Bill', 'Anders', 'Apollo', 'space', 'mission', 'It', 'first', 'photograph', 'taken', 'Earth', 'lunar', 'orbit', 'Millennium', 'nd', 'millennium', 'Centuries', 'th', 'century', 'th', 'century', 'st', 'century', 'Timelines', 'th', 'century', 'th', 'century', 'st', 'century', 'State', 'leaders', 'th', 'century', 'th', 'century', 'st', 'century', 'Decades', 'Categories', 'Births', 'Deaths', 'Establishments', 'Disestablishments', 'vteThe', 'th', 'century', 'began', 'January', 'MCMI', 'ended', 'December', 'MM', 'It', 'th', 'last', 'century', 'nd', 'millennium', 'marked', 'new', 'models', 'scientific', 'understanding', 'unprecedented', 'scopes', 'warfare', 'new', 'modes', 'communication', ' ...

# %%
     # Use tags fcn - Next step to using POS (Part of Speech) tags -

# %%
tags_list = text.tags

# %%
tags_list
# Out:
# [('[', 'JJ'),
#  ("'th", 'NNP'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'Wikipedia", 'NNP'),
#  ("'", 'POS'),
#  ("'Jump", 'NNP'),
#  ("'", 'POS'),
#  ("'content", 'NNP'),
#  ("'", 'POS'),
#  ("'menu", 'NNP'),
#  ("'", 'POS'),
#  ("'menu", 'NNP'),
#  ("'", 'POS'),
#  ("'move", 'NNP'),
#  ("'", 'POS'),
#  ("'sidebar", 'NNP'),
#  ("'", 'POS'),
#  ("'hide", 'NNP'),
#  ("'", 'POS'),
#  ("'Navigation", 'NN'),
#  ("'pageContentsCurrent", 'NNP'),
#  ("'", 'POS'),
#  ("'eventsRandom", 'NNP'),
#  ("'", 'POS'),
#  ("'articleAbout", 'IN'),
#  ("'WikipediaContact", 'NNP'),
#  ("'", 'POS'),
#  ("'us", 'NNP'),
#  ("'", 'POS'),
#  ("'HelpLearn", 'NNP'),
#  ("'", 'POS'),
#  ("'editCommunity", 'NNP'),
#  ("'", 'POS'),
#  ("'portalRecent", 'NNP'),
#  ("'", 'POS'),
#  ("'file", 'IN'),
#  ("'Search", 'NNP'),
#  ("'", 'POS'),
#  ("'Search", 'NNP'),
#  ("'", 'POS'),
#  ("'Appearance", 'NN'),
#  ("'Donate", 'NNP'),
#  ("'", 'POS'),
#  ("'Create", 'NNP'),
#  ("'", 'POS'),
#  ("'account", 'NNP'),
#  ("'", 'POS'),
#  ("'Log", 'NNP'),
#  ("'", 'POS'),
#  ("'Personal", 'NNP'),
#  ("'", 'POS'),
#  ("'tools", 'NNS'),
#  ("'", 'POS'),
#  ("'Donate", 'NNP'),
#  ("'", 'POS'),
#  ("'Create", 'NNP'),
#  ("'", 'POS'),
#  ("'account", 'NNP'),
#  ("'", 'POS'),
#  ("'Log", 'NNP'),
#  ("'", 'POS'),
#  ("'Pages", 'NNS'),
#  ("'", 'POS'),
#  ("'logged", 'VBD'),
#  ("'editors", 'NNS'),
#  ("'", 'POS'),
#  ("'learn", 'NNP'),
#  ("'", 'POS'),
#  ("'Contents", 'NNS'),
#  ("'", 'POS'),
#  ("'move", 'NNP'),
#  ("'", 'POS'),
#  ("'sidebar", 'NNP'),
#  ("'", 'POS'),
#  ("'hide", 'NNP'),
#  ("'", 'POS'),
#  ("'Summary", 'NNP'),
#  ("'", 'POS'),
#  ("'Nature", 'NN'),
#  ("'innovation", 'NNP'),
#  ("'", 'POS'),
#  ("'change", 'NNP'),
#  ("'", 'POS'),
#  ("'Social", 'NNP'),
#  ("'", 'POS'),
#  ("'change", 'NNP'),
#  ("'", 'POS'),
#  ("'th", 'NNP'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'Wars", 'NNS'),
#  ("'", 'POS'),
#  ("'politics", 'NNS'),
#  ("'", 'POS'),
#  ("'Culture", 'NN'),
#  ("'entertainment", 'NNP'),
#  ("'", 'POS'),
#  ("'Toggle", 'NNP'),
#  ("'", 'POS'),
#  ("'Culture", 'NN'),
#  ("'entertainment", 'NNP'),
#  ("'", 'POS'),
#  ("'subsection", 'NN'),
#  ("'Film", 'NNP'),
#  ("'", 'POS'),
#  ("'television", 'NN'),
#  ("'theatre", 'NNP'),
#  ("'", 'POS'),
#  ("'Video", 'NNP'),
#  ("'", 'POS'),
#  ("'games", 'NNS'),
#  ("'", 'POS'),
#  ("'architecture", 'NN'),
#  ("'Sport", 'NNP'),
#  ("'", 'POS'),
#  ("'Science", 'NN'),
#  ("'Toggle", 'NNP'),
#  ("'", 'POS'),
#  ("'Science", 'NN'),
#  ("'subsection", 'NNP'),
#  ("'", 'POS'),
#  ("'Mathematics", 'NNS'),
#  ("'", 'POS'),
#  ("'Physics", 'NNS'),
#  ("'", 'POS'),
#  ("'Astronomy", 'NNP'),
#  ("'", 'POS'),
#  ("'Agriculture", 'NN'),
#  ("'Biology", 'NNP'),
#  ("'", 'POS'),
#  ("'Medicine", 'NNP'),
#  ("'", 'POS'),
#  ("'Notable", 'JJ'),
#  ("'diseases", 'NNS'),
#  ("'", 'POS'),
#  ("'Energy", 'NNP'),
#  ("'", 'POS'),
#  ("'environment", 'NNP'),
#  ("'", 'POS'),
#  ("'Engineering", 'VBG'),
#  ("'technology", 'NNP'),
#  ("'", 'POS'),
#  ("'Toggle", 'NNP'),
#  ("'", 'POS'),
#  ("'Engineering", 'VBG'),
#  ("'technology", 'NNP'),
#  ("'", 'POS'),
#  ("'subsection", 'NN'),
#  ("'Space", 'NNP'),
#  ("'", 'POS'),
#  ("'exploration", 'NN'),
#  ("'Religion", 'NNP'),
#  ("'", 'POS'),
#  ("'Economics", 'NNS'),
#  ("'", 'POS'),
#  ("'also", 'NNP'),
#  ("'", 'POS'),
#  ("'References", 'NNS'),
#  ("'", 'POS'),
#  ("'Sources", 'NNS'),
#  ("'", 'POS'),
#  ("'Further", 'PRP'),
#  ("'reading", 'VBG'),
#  ("'External", 'NNP'),
#  ("'", 'POS'),
#  ("'links", 'NNS'),
#  ("'", 'POS'),
#  ("'Toggle", 'NNP'),
#  ("'", 'POS'),
#  ("'table", 'JJ'),
#  ("'contents", 'NNS'),
#  ("'", 'POS'),
#  ("'th", 'NNP'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'languages", 'NNS'),
#  ("'", 'POS'),
#  ("'AfrikaansAlemannisch", 'NNP'),
#  ("'", 'POS'),
#  ("'xad", 'NNP'),
#  ("'", 'POS'),
#  ("'nglisc", 'NNP'),
#  ("'", 'POS'),
#  ("'Aragon", 'NNP'),
#  ("'", 'POS'),
#  ("'sArpetanAsturianu", 'NNP'),
#  ("'", 'POS'),
#  ("'Az", 'NNP'),
#  ("'", 'POS'),
#  ("'rbaycanca", 'NNP'),
#  ("'", 'POS'),
#  ("'Basa", 'NNP'),
#  ("'", 'POS'),
#  ("'Bali", 'NNP'),
#  ("'", 'POS'),
#  ('B', 'NNP'),
#  ("'", 'POS'),
#  ('l', 'NN'),
#  ("'m", 'VBP'),
#  ('g', 'NN'),
#  ("'Basa", 'NNP'),
#  ("'", 'POS'),
#  ("'Banyumasan", 'NNP'),
#  ("'", 'POS'),
#  ("'BosanskiBrezhoneg", 'NNP'),
#  ("'", 'POS'),
#  ("'Catal", 'NNP'),
#  ("'", 'POS'),
#  ("'Cebuano", 'NNP'),
#  ("'", 'POS'),
#  ('e', 'NN'),
#  ("'tinaCymraegDansk", 'NNP'),
#  ("'", 'POS'),
#  ("'Davvis", 'NNP'),
#  ("'", 'POS'),
#  ("'megiellaDeutschEesti", 'NNP'),
#  ("'", 'POS'),
#  ("'Emili", 'NNP'),
#  ("'", 'POS'),
#  ('e', 'NN'),
#  ("'rumagn", 'NNP'),
#  ("'", 'POS'),
#  ('l', 'NN'),
#  ("'xad", 'NNP'),
#  ("'", 'POS'),
#  ("'Espa", 'NNP'),
#  ("'", 'POS'),
#  ("'uEuskara", 'NNP'),
#  ("'", 'POS'),
#  ("'Fiji", 'NNP'),
#  ("'", 'POS'),
#  ("'HindiF", 'NNP'),
#  ("'", 'POS'),
#  ("'roysktFran", 'NNP'),
#  ("'", 'POS'),
#  ("'aisFryskGaeilgeGaelgG", 'NNP'),
#  ("'", 'POS'),
#  ("'idhligGalego", 'NNP'),
#  ("'", 'POS'),
#  ("'Hak", 'NNP'),
#  ("'", 'POS'),
#  ('k', 'NN'),
#  ("'ng", 'NNP'),
#  ("'", 'POS'),
#  ("'xad", 'NNP'),
#  ("'", 'POS'),
#  ("'HornjoserbsceHrvatskiIdoIlokanoBahasa", 'NNP'),
#  ("'", 'POS'),
#  ("'IndonesiaInterlingua", 'NNP'),
#  ("'", 'POS'),
#  ("'slenskaItaliano", 'NNP'),
#  ("'", 'POS'),
#  ("'Jawa", 'NNP'),
#  ("'", 'POS'),
#  ("'KernowekKiswahili", 'NNP'),
#  ("'", 'POS'),
#  ("'KotavaKurd", 'NNP'),
#  ("'", 'POS'),
#  ("'Latga", 'NNP'),
#  ("'", 'POS'),
#  ("'uLatinaLatvie", 'NNP'),
#  ("'", 'POS'),
#  ("'uL", 'NNP'),
#  ("'", 'POS'),
#  ("'tzebuergesch", 'NNP'),
#  ("'", 'POS'),
#  ("'Lietuvi", 'NNP'),
#  ("'", 'POS'),
#  ("'LigureLimburgsLing", 'VBG'),
#  ("'laLingua", 'NNP'),
#  ("'", 'POS'),
#  ("'Franca", 'NNP'),
#  ("'", 'POS'),
#  ("'NovaLivvinkarjalaLa", 'NNP'),
#  ("'", 'POS'),
#  ("'LombardMagyar", 'NNP'),
#  ("'", 'POS'),
#  ("'M", 'NNP'),
#  ("'", 'POS'),
#  ("'ori", 'NNP'),
#  ("'", 'POS'),
#  ("'Bahasa", 'NNP'),
#  ("'", 'POS'),
#  ("'Melayu", 'NNP'),
#  ("'", 'POS'),
#  ("'M", 'NNP'),
#  ("'", 'POS'),
#  ("'ng", 'NNP'),
#  ("'", 'POS'),
#  ("'d", 'MD'),
#  ("'ng", 'NNP'),
#  ("'", 'POS'),
#  ("'ng", 'NNP'),
#  ("'", 'POS'),
#  ("'Mirand", 'NNP'),
#  ("'", 'POS'),
#  ("'N", 'NNP'),
#  ("'", 'POS'),
#  ("'huatlNederlandsNedersaksies", 'NNS'),
#  ("'", 'POS'),
#  ("'Napulitano", 'NNP'),
#  ("'", 'POS'),
#  ("'NordfriiskNorsk", 'NNP'),
#  ("'", 'POS'),
#  ("'bokm", 'NNP'),
#  ("'", 'POS'),
#  ("'lNorsk", 'NNP'),
#  ("'", 'POS'),
#  ("'nynorskNouormandNovialOccitan", 'NNP'),
#  ("'", 'POS'),
#  ('O', 'NNP'),
#  ("'", 'POS'),
#  ("'zbekcha", 'NNP'),
#  ("'", 'POS'),
#  ("'Papiamentu", 'NNP'),
#  ("'", 'POS'),
#  ("'Plattd", 'NNP'),
#  ("'", 'POS'),
#  ("'tschPolskiPortugu", 'NNP'),
#  ("'", 'POS'),
#  ("'sRom", 'NNP'),
#  ("'", 'POS'),
#  ("'RumantschRuna", 'NNP'),
#  ("'", 'POS'),
#  ("'Simi", 'NNP'),
#  ("'", 'POS'),
#  ("'ScotsSeelterskSesotho", 'NNP'),
#  ("'", 'POS'),
#  ("'sa", 'NNP'),
#  ("'", 'POS'),
#  ("'LeboaShqipSicilianu", 'NNP'),
#  ("'", 'POS'),
#  ("'ina", 'NNP'),
#  ("'", 'POS'),
#  ('l', 'NN'),
#  ("'nskiSoomaaliga", 'NNP'),
#  ("'", 'POS'),
#  ("'srpskiSrpskohrvatski", 'NNP'),
#  ("'", 'POS'),
#  ("'SundaSuomiSvenskaTagalog", 'NNP'),
#  ("'", 'POS'),
#  ("'Taqbaylit", 'NNP'),
#  ("'", 'POS'),
#  ("'tatar", 'NNP'),
#  ("'", 'POS'),
#  ('a', 'DT'),
#  ("'T", 'NNP'),
#  ("'", 'POS'),
#  ("'rk", 'NNP'),
#  ("'", 'POS'),
#  ("'eT", 'NNP'),
#  ("'", 'POS'),
#  ("'rkmen", 'NNS'),
#  ("'", 'POS'),
#  ('e', 'NN'),
#  ('V', 'NNP'),
#  ("'", 'POS'),
#  ("'netoTi", 'NNP'),
#  ("'", 'POS'),
#  ("'ng", 'NNP'),
#  ("'", 'POS'),
#  ("'Vi", 'NNP'),
#  ("'", 'POS'),
#  ("'tVolap", 'NNP'),
#  ("'", 'POS'),
#  ("'kV", 'NNP'),
#  ("'", 'POS'),
#  ("'xad", 'NNP'),
#  ("'", 'POS'),
#  ("'ZazakiZe", 'NNP'),
#  ("'", 'POS'),
#  ("'uws", 'NNP'),
#  ("'", 'POS'),
#  ("'emait", 'NNP'),
#  ("'", 'POS'),
#  ("'ka", 'NNP'),
#  ("'", 'POS'),
#  ("'xad", 'NNP'),
#  ("'", 'POS'),
#  ("'Tol", 'NNP'),
#  ("'", 'POS'),
#  ('i', 'NN'),
#  ("'Edit", 'NNP'),
#  ("'", 'POS'),
#  ("'links", 'NNS'),
#  ("'", 'POS'),
#  ("'ReadEditView", 'NNP'),
#  ("'", 'POS'),
#  ("'history", 'NNP'),
#  ("'", 'POS'),
#  ("'Tools", 'NNS'),
#  ("'", 'POS'),
#  ("'Tools", 'NNS'),
#  ("'", 'POS'),
#  ("'move", 'NNP'),
#  ("'", 'POS'),
#  ("'sidebar", 'NNP'),
#  ("'", 'POS'),
#  ("'hide", 'NNP'),
#  ("'", 'POS'),
#  ("'Actions", 'NNS'),
#  ("'", 'POS'),
#  ("'ReadEditView", 'NNP'),
#  ("'", 'POS'),
#  ("'history", 'NNP'),
#  ("'", 'POS'),
#  ("'General", 'NNP'),
#  ("'", 'POS'),
#  ("'What", 'WP'),
#  ("'links", 'NNS'),
#  ("'", 'POS'),
#  ("'hereRelated", 'VBD'),
#  ("'fileSpecial", 'NNP'),
#  ("'", 'POS'),
#  ("'pagesPermanent", 'NNP'),
#  ("'", 'POS'),
#  ("'linkPage", 'NN'),
#  ("'informationCite", 'NNP'),
#  ("'", 'POS'),
#  ("'shortened", 'VBD'),
#  ("'QR", 'NNP'),
#  ("'", 'POS'),
#  ("'code", 'NNP'),
#  ("'", 'POS'),
#  ("'Print", 'NNP'),
#  ("'", 'POS'),
#  ("'export", 'NNP'),
#  ("'", 'POS'),
#  ("'PDFPrintable", 'JJ'),
#  ("'version", 'NNP'),
#  ("'", 'POS'),
#  ("'In", 'NNP'),
#  ("'", 'POS'),
#  ("'projects", 'NNS'),
#  ("'", 'POS'),
#  ("'Wikimedia", 'NNP'),
#  ("'", 'POS'),
#  ("'CommonsWikiquoteWikidata", 'NNP'),
#  ("'", 'POS'),
#  ("'item", 'NNP'),
#  ("'", 'POS'),
#  ("'Appearance", 'NN'),
#  ("'move", 'NNP'),
#  ("'", 'POS'),
#  ("'sidebar", 'NNP'),
#  ("'", 'POS'),
#  ("'hide", 'NNP'),
#  ("'", 'POS'),
#  ("'From", 'IN'),
#  ("'Wikipedia", 'NNP'),
#  ("'", 'POS'),
#  ("'encyclopedia", 'NNP'),
#  ("'", 'POS'),
#  ("'hundred", 'VBD'),
#  ("'years", 'NNS'),
#  ("'", 'POS'),
#  ("'For", 'NNP'),
#  ("'", 'POS'),
#  ("'uses", 'NNS'),
#  ("'", 'POS'),
#  ("'see", 'NNP'),
#  ("'", 'POS'),
#  ("'th", 'NNP'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'disambiguation", 'NN'),
#  ("'Earthrise", 'NNP'),
#  ("'", 'POS'),
#  ("'December", 'NNP'),
#  ("'", 'POS'),
#  ("'astronaut", 'NNP'),
#  ("'", 'POS'),
#  ("'William", 'NNP'),
#  ("'", 'POS'),
#  ("'Bill", 'NNP'),
#  ("'", 'POS'),
#  ("'Anders", 'NNS'),
#  ("'", 'POS'),
#  ("'Apollo", 'NNP'),
#  ("'", 'POS'),
#  ("'space", 'NNP'),
#  ("'", 'POS'),
#  ("'mission", 'NN'),
#  ("'It", 'NNP'),
#  ("'", 'POS'),
#  ("'first", 'NNP'),
#  ("'", 'POS'),
#  ("'photograph", 'NNP'),
#  ("'", 'POS'),
#  ("'lunar", 'NNP'),
#  ("'", 'POS'),
#  ("'nd", 'NNP'),
#  ("'", 'POS'),
#  ("'millennium", 'NN'),
#  ("'Centuries", 'NNS'),
#  ("'", 'POS'),
#  ("'th", 'NNP'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'th", 'NNP'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'st", 'NNP'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'Timelines", 'NNS'),
#  ("'", 'POS'),
#  ("'th", 'NNP'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'th", 'NNP'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'st", 'NNP'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'State", 'NNP'),
#  ("'", 'POS'),
#  ("'leaders", 'NNS'),
#  ("'", 'POS'),
#  ("'th", 'NNP'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'th", 'NNP'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'st", 'NNP'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'Decades", 'NNS'),
#  ("'", 'POS'),
#  ("'Categories", 'NNS'),
#  ("'", 'POS'),
#  ("'Births", 'NNS'),
#  ("'", 'POS'),
#  ("'Deaths", 'NNS'),
#  ("'", 'POS'),
#  ("'Establishments", 'NNS'),
#  ("'", 'POS'),
#  ("'Disestablishments", 'NNS'),
#  ("'", 'POS'),
#  ("'vteThe", 'NNP'),
#  ("'", 'POS'),
#  ("'th", 'NNP'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'began", 'NNP'),
#  ("'", 'POS'),
#  ("'January", 'NNP'),
#  ("'", 'POS'),
#  ("'MCMI", 'NNP'),
#  ("'", 'POS'),
#  ("'ended", 'VBD'),
#  ("'December", 'NNP'),
#  ("'", 'POS'),
#  ("'MM", 'NNP'),
#  ("'", 'POS'),
#  ("'It", 'NNP'),
#  ("'", 'POS'),
#  ("'th", 'NNP'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'nd", 'NNP'),
#  ("'", 'POS'),
#  ("'millennium", 'NN'),
#  ("'marked", 'VBD'),
#  ("'new", 'NNP'),
#  ("'", 'POS'),
#  ("'models", 'NNS'),
#  ("'", 'POS'),
#  ("'scientific", 'NNP'),
#  ("'", 'POS'),
#  ("'understanding", 'VBG'),
#  ("'unprecedented", 'VBD'),
#  ("'scopes", 'NNS'),
#  ("'", 'POS'),
#  ("'warfare", 'NNP'),
#  ("'", 'POS'),
#  ("'new", 'NNP'),
#  ("'", 'POS'),
#  ("'modes", 'NNS'),
#  ("'", 'POS'),
#  ("'communication", 'NN'),
#  ("'would", 'MD'),
#  ("'operate", 'NNP'),
#  ("'", 'POS'),
#  ("'nearly", 'RB'),
#  ("'instant", 'NNP'),
#  ("'", 'POS'),
#  ("'speeds", 'NNS'),
#  ("'", 'POS'),
#  ("'new", 'NNP'),
#  ("'", 'POS'),
#  ("'forms", 'NNS'),
#  ("'", 'POS'),
#  ("'art", 'NNP'),
#  ("'", 'POS'),
#  ("'entertainment", 'NNP'),
#  ("'", 'POS'),
#  ("'Population", 'NN'),
#  ("'growth", 'NNP'),
#  ("'", 'POS'),
#  ("'also", 'NNP'),
#  ("'", 'POS'),
#  ("'unprecedented", 'VBD'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'started", 'VBD'),
#  ("'around", 'IN'),
#  ("'billion", 'NNP'),
#  ("'", 'POS'),
#  ("'ended", 'VBD'),
#  ("'around", 'IN'),
#  ("'billion", 'NNP'),
#  ("'", 'POS'),
#  ("'th", 'NNP'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'dominated", 'VBD'),
#  ("'significant", 'NNP'),
#  ("'", 'POS'),
#  ("'geopolitical", 'JJ'),
#  ("'events", 'NNS'),
#  ("'", 'POS'),
#  ("'reshaped", 'VBD'),
#  ("'political", 'JJ'),
#  ("'social", 'NNP'),
#  ("'", 'POS'),
#  ("'structure", 'NN'),
#  ("'globe", 'NNP'),
#  ("'", 'POS'),
#  ("'World", 'NNP'),
#  ("'", 'POS'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ('I', 'PRP'),
#  ("'flu", 'NNP'),
#  ("'", 'POS'),
#  ("'pandemic", 'NNP'),
#  ("'", 'POS'),
#  ("'World", 'NNP'),
#  ("'", 'POS'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ("'II", 'NNP'),
#  ("'", 'POS'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ("'Unprecedented", 'VBD'),
#  ("'advances", 'NNS'),
#  ("'", 'POS'),
#  ("'science", 'NN'),
#  ("'technology", 'NNP'),
#  ("'", 'POS'),
#  ("'defined", 'VBD'),
#  ("'modern", 'NNP'),
#  ("'", 'POS'),
#  ("'including", 'VBG'),
#  ("'advent", 'NNP'),
#  ("'", 'POS'),
#  ("'weapons", 'NNS'),
#  ("'", 'POS'),
#  ("'power", 'JJR'),
#  ("'space", 'NNP'),
#  ("'", 'POS'),
#  ("'exploration", 'NN'),
#  ("'analog", 'NNP'),
#  ("'", 'POS'),
#  ("'digital", 'NNP'),
#  ("'", 'POS'),
#  ("'computing", 'VBG'),
#  ("'continuing", 'VBG'),
#  ("'advancement", 'NNP'),
#  ("'", 'POS'),
#  ("'transportation", 'NN'),
#  ("'including", 'VBG'),
#  ("'powered", 'VBD'),
#  ("'flight", 'NNP'),
#  ("'", 'POS'),
#  ("'automobile", 'IN'),
#  ("'sixth", 'NNP'),
#  ("'", 'POS'),
#  ("'mass", 'NNP'),
#  ("'", 'POS'),
#  ("'extinction", 'NN'),
#  ("'event", 'NNP'),
#  ("'", 'POS'),
#  ("'Holocene", 'NNP'),
#  ("'", 'POS'),
#  ("'extinction", 'NN'),
#  ("'continued", 'VBD'),
#  ("'human", 'NNP'),
#  ("'", 'POS'),
#  ("'conservation", 'NN'),
#  ("'efforts", 'NNS'),
#  ("'", 'POS'),
#  ("'increased", 'VBD'),
#  ("'themes", 'NNS'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'include", 'NNP'),
#  ("'", 'POS'),
#  ("'decolonization", 'NN'),
#  ("'nationalism", 'NNP'),
#  ("'", 'POS'),
#  ("'globalization", 'NN'),
#  ("'new", 'NNP'),
#  ("'", 'POS'),
#  ("'forms", 'NNS'),
#  ("'", 'POS'),
#  ("'intergovernmental", 'NNP'),
#  ("'", 'POS'),
#  ("'organizations", 'NNS'),
#  ("'", 'POS'),
#  ("'Democracy", 'NNP'),
#  ("'", 'POS'),
#  ("'women", 'NNS'),
#  ("'", 'POS'),
#  ("'earned", 'VBD'),
#  ("'right", 'NNP'),
#  ("'", 'POS'),
#  ("'", 'POS'),
#  ("'countries", 'NNS'),
#  ("'", 'POS'),
#  ("'world", 'NNP'),
#  ("'", 'POS'),
#  ("'Cultural", 'NNP'),
#  ("'", 'POS'),
#  ("'homogenization", 'NN'),
#  ("'began", 'NNP'),
#  ("'", 'POS'),
#  ("'developments", 'NNS'),
#  ("'", 'POS'),
#  ("'emerging", 'VBG'),
#  ("'transportation", 'NNP'),
#  ("'", 'POS'),
#  ("'information", 'NN'),
#  ("'communications", 'NNS'),
#  ("'", 'POS'),
#  ("'technology", 'NNP'),
#  ("'", 'POS'),
#  ("'influences", 'NNS'),
#  ("'", 'POS'),
#  ("'Western", 'NNP'),
#  ("'", 'POS'),
#  ("'culture", 'NN'),
#  ("'international", 'NNP'),
#  ("'", 'POS'),
#  ("'corporations", 'NNS'),
#  ("'", 'POS'),
#  ("'arguably", 'RB'),
#  ("'truly", 'NNP'),
#  ("'", 'POS'),
#  ("'economy", 'NNP'),
#  ("'", 'POS'),
#  ("'th", 'NNP'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'reduced", 'VBD'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'saw", 'NNP'),
#  ("'", 'POS'),
#  ("'rising", 'VBG'),
#  ("'standards", 'NNS'),
#  ("'", 'POS'),
#  ("'living", 'VBG'),
#  ("'world", 'NNP'),
#  ("'", 'POS'),
#  ("'population", 'NN'),
#  ("'growth", 'NNP'),
#  ("'", 'POS'),
#  ("'awareness", 'NNP'),
#  ("'", 'POS'),
#  ("'environmental", 'NNP'),
#  ("'", 'POS'),
#  ("'degradation", 'NN'),
#  ("'ecological", 'JJ'),
#  ("'extinction", 'NNP'),
#  ("'", 'POS'),
#  ("'Automobiles", 'NNS'),
#  ("'", 'POS'),
#  ("'airplanes", 'NNS'),
#  ("'", 'POS'),
#  ("'home", 'NNP'),
#  ("'", 'POS'),
#  ("'appliances", 'NNS'),
#  ("'", 'POS'),
#  ("'video", 'NNP'),
#  ("'", 'POS'),
#  ("'audio", 'NNP'),
#  ("'", 'POS'),
#  ("'recording", 'VBG'),
#  ("'saw", 'NNP'),
#  ("'", 'POS'),
#  ("'mass", 'NNP'),
#  ("'", 'POS'),
#  ("'adoption", 'NN'),
#  ("'These", 'JJ'),
#  ("'developments", 'NNS'),
#  ("'", 'POS'),
#  ("'possible", 'JJ'),
#  ("'exploitation", 'NNP'),
#  ("'", 'POS'),
#  ("'fossil", 'NNP'),
#  ("'", 'POS'),
#  ("'fuel", 'NNP'),
#  ("'", 'POS'),
#  ("'resources", 'NNS'),
#  ("'", 'POS'),
#  ("'offered", 'VBD'),
#  ("'energy", 'NNP'),
#  ("'", 'POS'),
#  ("'easily", 'RB'),
#  ("'", 'POS'),
#  ("'portable", 'JJ'),
#  ("'also", 'NNP'),
#  ("'", 'POS'),
#  ("'caused", 'VBD'),
#  ("'concern", 'NNP'),
#  ("'", 'POS'),
#  ("'pollution", 'NN'),
#  ("'long", 'NNP'),
#  ("'", 'POS'),
#  ("'impact", 'NNP'),
#  ("'", 'POS'),
#  ("'environment", 'NNP'),
#  ("'", 'POS'),
#  ("'Humans", 'NNS'),
#  ("'", 'POS'),
#  ("'started", 'VBD'),
#  ("'space", 'NNP'),
#  ("'", 'POS'),
#  ("'taking", 'VBG'),
#  ("'first", 'NNP'),
#  ("'", 'POS'),
#  ("'footsteps", 'NNS'),
#  ("'", 'POS'),
#  ("'Great", 'NNP'),
#  ("'", 'POS'),
#  ("'advances", 'NNS'),
#  ("'", 'POS'),
#  ("'electricity", 'NNP'),
#  ("'", 'POS'),
#  ("'generation", 'NN'),
#  ("'telecommunications", 'NNS'),
#  ("'", 'POS'),
#  ("'allowed", 'VBD'),
#  ("'near", 'IN'),
#  ("'instantaneous", 'JJ'),
#  ("'worldwide", 'NNP'),
#  ("'", 'POS'),
#  ("'communication", 'NN'),
#  ("'ultimately", 'RB'),
#  ("'leading", 'VBG'),
#  ("'Internet", 'NNP'),
#  ("'", 'POS'),
#  ("'Meanwhile", 'IN'),
#  ("'advances", 'NNS'),
#  ("'", 'POS'),
#  ("'medical", 'JJ'),
#  ("'technology", 'NNP'),
#  ("'", 'POS'),
#  ("'resulted", 'VBD'),
#  ("'near", 'IN'),
#  ("'eradication", 'NNP'),
#  ("'", 'POS'),
#  ("'eradication", 'NN'),
#  ("'", 'POS'),
#  ("'infectious", 'JJ'),
#  ("'diseases", 'NNS'),
#  ("'", 'POS'),
#  ("'well", 'NNP'),
#  ("'", 'POS'),
#  ("'opening", 'VBG'),
#  ("'avenue", 'NNP'),
#  ("'", 'POS'),
#  ("'biological", 'JJ'),
#  ("'genetic", 'JJ'),
#  ("'engineering", 'VBG'),
#  ("'Scientific", 'NNP'),
#  ("'", 'POS'),
#  ("'discoveries", 'NNS'),
#  ("'", 'POS'),
#  ("'theory", 'NNP'),
#  ("'", 'POS'),
#  ("'relativity", 'NNP'),
#  ("'", 'POS'),
#  ("'quantum", 'NNP'),
#  ("'", 'POS'),
#  ("'physics", 'NNS'),
#  ("'", 'POS'),
#  ("'profoundly", 'RB'),
#  ("'changed", 'VBD'),
#  ("'foundational", 'NNP'),
#  ("'", 'POS'),
#  ("'models", 'NNS'),
#  ("'", 'POS'),
#  ("'physical", 'JJ'),
#  ("'science", 'NNP'),
#  ("'", 'POS'),
#  ("'forcing", 'VBG'),
#  ("'scientists", 'NNS'),
#  ("'", 'POS'),
#  ("'complex", 'NNP'),
#  ("'", 'POS'),
#  ("'previously", 'RB'),
#  ("'believed", 'VBD'),
#  ("'dashing", 'VBG'),
#  ("'hopes", 'NNS'),
#  ("'", 'POS'),
#  ("'fears", 'NNS'),
#  ("'", 'POS'),
#  ("'th", 'NNP'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'details", 'NNS'),
#  ("'", 'POS'),
#  ("'scientific", 'NNP'),
#  ("'", 'POS'),
#  ("'knowledge", 'NNP'),
#  ("'", 'POS'),
#  ("'filled", 'VBD'),
#  ("'Summary", 'NNP'),
#  ("'", 'POS'),
#  ("'edit", 'NNP'),
#  ("'", 'POS'),
#  ("'At", 'NNP'),
#  ("'", 'POS'),
#  ("'beginning", 'VBG'),
#  ("'period", 'NNP'),
#  ("'", 'POS'),
#  ("'Empire", 'NNP'),
#  ("'", 'POS'),
#  ("'world", 'NNP'),
#  ("'", 'POS'),
#  ("'nation", 'NNP'),
#  ("'", 'POS'),
#  ("'acted", 'VBD'),
#  ("'world", 'NNP'),
#  ("'", 'POS'),
#  ("'policeman", 'NNP'),
#  ("'", 'POS'),
#  ("'century", 'NNP'),
#  ("'", 'POS'),
#  ("'World", 'NNP'),
#  ("'", 'POS'),
#  ("'powers", 'NNS'),
#  ("'", 'POS'),
#  ("'empires", 'NNS'),
#  ("'", 'POS'),
#  ("'First", 'NNP'),
#  ("'", 'POS'),
#  ("'World", 'NNP'),
#  ("'", 'POS'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ("'Technological", 'JJ'),
#  ("'advancements", 'NNS'),
#  ("'", 'POS'),
#  ("'World", 'NNP'),
#  ("'", 'POS'),
#  ("'War", 'NNP'),
#  ("'", 'POS'),
#  ('I', 'PRP'),
#  ("'changed", 'VBD'),
#  ("'way", 'NNP'),
#  ("'", 'POS'),
#  ("'war", 'NNP'),
#  ("'", 'POS'),
#  ("'fought", 'NNP'),
#  ("'", 'POS'),
#  ("'new", 'NNP'),
#  ("'", 'POS'),
#  ("'inventions", 'NNS'),
#  ("'", 'POS'),
#  ("'tanks", 'NNS'),
#  ("'", 'POS'),
#  ("'chemical", 'JJ'),
#  ("'weapons", 'NNS'),
#  ...]

# %% [markdown]
# ### 7) Create a list of the Top10 POS tags for words that appear in the article

# %%
    # Group the words by its part of speech, and narrow it down to largest 10 groups on list

# %%
df_text = pd.DataFrame(tags_list)
df_text.columns = [ '# of Words', 'Word type']
df_t=df_text.groupby('Word type').count().reset_index()
top10=df_t.nlargest(10, '# of Words')

# %% [markdown]
# ### 8) Plot this list in a bar chart using the seaborn library

# %%
    # Creating bar plot

# %%
plt.figure(figsize = (10, 5))
with sns.dark_palette("xkcd:blue", 10):
      sns.barplot(x = "# of Words", y = "Word type",
     saturation = 0.9, data = top10).set_title("Key Events of 20th Century - top 10 word types used")

# %% [markdown]
# ### 9) Create 3 bar plots with the top 15 POS labels - 1 each for nouns, verbs, and adjectives

# %% [markdown]
# #### NOUNS

# %%
# Filter out Nouns - singular nouns (NN), pluralized nouns (NNS), and proper nouns (NNP)

# %%
df = df_text[(df_text['Word type'] == "NN") | (df_text['Word type'] == "NNS") | (df_text['Word type'] == "NNS")]
df.columns = ['Noun', 'Occurrences']
x = df.groupby('Noun').count().reset_index()
y = x.sort_values(by = ['Occurrences'], ascending=False)
top15 = y.nlargest(15, 'Occurrences')

# %%
top15
# Out:
#             Noun  Occurrences
# 251   'countries           20
# 148       'Union           17
# 601       'years           13
# 594        'wars           10
# 612            p           10
# 288    'diseases           10
# 106  'Population            9
# 475      'powers            8
# 256     'culture            8
# 169         'age            7
# 471  'population            7
# 75        'James            7
# 348       'games            7
# 262      'deaths            7
# 242   'conflicts            7

# %%
# Create bar plot of top 15 used nouns

# %%
plt.figure(figsize=(10, 5))
with sns.dark_palette("xkcd:blue", 15):
      sns.barplot(x='Noun', y='Occurrences',
      saturation=0.9, data = top15).set_title("Key Events of 20th century - top 15 used nouns")

# %% [markdown]
# There are only 3 nouns that have more than 10 occurrences in article:  countries, Union, years.

# %% [markdown]
# #### VERBS

# %%
# Filter out Verbs - base form verbs - take (VB); past tense verbs - took (VBD); gerund/present participle verb - taking (VBG)
#                    past participle verbs - taken (VBN); sing. present, non-3d verbs- take (VBP)
#                    3rd person sing. present verbs - takes (VBZ)

# %%
df = df_text[(df_text['Word type'] == "VB") | (df_text['Word type'] == "VBD") | (df_text['Word type'] == "VBG")| (df_text['Word type'] == "VBN") | (df_text['Word type'] == "VBP")| (df_text['Word type'] == "VBZ")]
df.columns = ['Verb', 'Occurrences']
x = df.groupby('Verb').count().reset_index()
y = x.sort_values(by = ['Occurrences'], ascending=False)
top15 = y.nlargest(15, 'Occurrences')

# %%
# Create bar plot of top 15 used verbs

# %%
plt.figure(figsize=(10, 5))
with sns.dark_palette("xkcd:blue", 15):
      sns.barplot(x='Verb', y='Occurrences',
      saturation=0.9, data = top15).set_title("Key Events of 20th century - top 15 used verbs")

# %% [markdown]
# There is a lot of variability between the most used verb and the 15th ranked verb: 26 occurrences (31-5).

# %% [markdown]
# #### ADJECTIVES

# %%
# Filter out Adjectives - 'big' adjectives (JJ), comparative 'bigger' adjectivess (JJR), and superlative 'biggest' adjectives (JJS)

# %%
df = df_text[(df_text['Word type'] == "JJ") | (df_text['Word type'] == "JJR") | (df_text['Word type'] == "JJS")]
df.columns = ['Adjective', 'Occurrences']
x = df.groupby('Adjective').count().reset_index()
y = x.sort_values(by = ['Occurrences'], ascending=False)
top15 = y.nlargest(15, 'Occurrences')

# %%
# Create bar plot of top 15 used adjectives

# %%
plt.figure(figsize=(10, 5))
with sns.dark_palette("xkcd:blue", 15):
      sns.barplot(x='Adjective', y='Occurrences',
      saturation=0.9, data = top15).set_title("Key Events of 20th century - top 15 used adjectives")

# %% [markdown]
# The 4 most used adjectives range from 6 - 14 occurrences. The occurrences of the other 11 adjectives range from 3 - 5.

# %% [markdown]
# ### 10.) Create a dataframe with the countries and the number of times they're mentioned in your text
# ### (remember -you'll neeed to use the countries lookup list if you didn't scrape one in the previous task).

# %% [markdown]
# ### Counting country occurrences

# %%
# 1st step -extract all of the words from the tokenized data

# %%
listToStr = ' '.join([str(elem) for elem in filtered])

print(listToStr)
# Out:
# th century Wikipedia Jump content Main menu Main menu move sidebar hide Navigation Main pageContentsCurrent eventsRandom articleAbout WikipediaContact us Contribute HelpLearn editCommunity portalRecent changesUpload file Search Search Appearance Donate Create account Log Personal tools Donate Create account Log Pages logged editors learn ContributionsTalk Contents move sidebar hide Top Summary Nature innovation change Social change Earth end th century Wars politics Culture entertainment Toggle Culture entertainment subsection Music Film television theatre Video games Art architecture Sport Science Toggle Science subsection Mathematics Physics Astronomy Agriculture Biology Medicine Notable diseases Energy environment Engineering technology Toggle Engineering technology subsection Space exploration Religion Economics See also References Sources Further reading External links Toggle table contents th century languages AfrikaansAlemannisch xad nglisc Aragon sArpetanAsturianu Az rbaycanca Basa Bali B l m g Basa Banyumasan BosanskiBrezhoneg Catal Cebuano e tinaCymraegDansk Davvis megiellaDeutschEesti Emili e rumagn l xad Espa olEsperantoEstreme uEuskara Fiji HindiF roysktFran aisFryskGaeilgeGaelgG idhligGalego Hak k ng xad HornjoserbsceHrvatskiIdoIlokanoBahasa IndonesiaInterlingua slenskaItaliano Jawa KernowekKiswahili KotavaKurd Latga uLatinaLatvie uL tzebuergesch Lietuvi LigureLimburgsLing laLingua Franca NovaLivvinkarjalaLa lojban LombardMagyar M ori Bahasa Melayu M ng d ng ng Mirand N huatlNederlandsNedersaksies Napulitano NordfriiskNorsk bokm lNorsk nynorskNouormandNovialOccitan O zbekcha Papiamentu Plattd tschPolskiPortugu sRom RumantschRuna Simi ScotsSeelterskSesotho sa LeboaShqipSicilianu Simple EnglishSloven inaSloven ina l nskiSoomaaliga srpskiSrpskohrvatski SundaSuomiSvenskaTagalog Taqbaylit tatar a T rk eT rkmen e V netoTi ng Vi tVolap kV roWalonWinaray xad ZazakiZe uws emait ka xad Tol i Edit links ArticleTalk English ReadEditView history Tools Tools move sidebar hide Actions ReadEditView history General What links hereRelated changesUpload fileSpecial pagesPermanent linkPage informationCite pageGet shortened URLDownload QR code Print export Download PDFPrintable version In projects Wikimedia CommonsWikiquoteWikidata item Appearance move sidebar hide From Wikipedia free encyclopedia One hundred years For uses see th century disambiguation Earthrise taken December astronaut William Bill Anders Apollo space mission It first photograph taken Earth lunar orbit Millennium nd millennium Centuries th century th century st century Timelines th century th century st century State leaders th century th century st century Decades Categories Births Deaths Establishments Disestablishments vteThe th century began January MCMI ended December MM It th last century nd millennium marked new models scientific understanding unprecedented scopes warfare new modes communication would operate nearly instant speeds new forms art entertainment Population growth also unprecedented century started around billion people ended around billion th century dominated significant geopolitical events reshaped political social structure globe World War I Spanish flu pandemic World War II Cold War Unprecedented advances science technology defined modern era including advent nuclear weapons nuclear power space exploration shift analog digital computing continuing advancement transportation including powered flight automobile Earth sixth mass extinction event Holocene extinction continued human conservation efforts increased Major themes century include decolonization nationalism globalization new forms intergovernmental organizations Democracy spread women earned right vote many countries world Cultural homogenization began developments emerging transportation information communications technology popular music influences Western culture international corporations arguably truly global economy end th century Poverty reduced century saw rising standards livi ...

# %%
# Create a count for the countries
# Use the regular expression W+ inside a Counter() function to store results in a dictionary so that you can see how frequently each of the ountries appear

all_counts = Counter(re.sub(r'\W+', ' ', data).split())

# %%
all_counts
# Out:
# Counter({'the': 632,
#          'of': 383,
#          'and': 364,
#          'in': 254,
#          'to': 148,
#          'The': 126,
#          'a': 100,
#          'century': 97,
#          'was': 82,
#          'by': 74,
#          'as': 69,
#          '20th': 57,
#          'with': 55,
#          's': 49,
#          'World': 48,
#          'were': 44,
#          'for': 43,
#          'world': 43,
#          'first': 42,
#          'War': 41,
#          'from': 39,
#          'on': 39,
#          'many': 36,
#          'Ð': 33,
#          'à': 32,
#          'United': 31,
#          'became': 30,
#          'edit': 29,
#          'â': 27,
#          'States': 25,
#          'Retrieved': 25,
#          'Ñ': 24,
#          'developed': 24,
#          '1': 23,
#          'other': 22,
#          'that': 22,
#          'music': 22,
#          'which': 22,
#          'an': 22,
#          'Soviet': 22,
#          'at': 21,
#          'end': 21,
#          '6': 21,
#          'In': 21,
#          'during': 21,
#          'new': 21,
#          'such': 21,
#          'A': 21,
#          'ISBNÂ': 21,
#          'countries': 20,
#          'Empire': 20,
#          'Europe': 20,
#          'people': 19,
#          'war': 19,
#          'Union': 19,
#          'is': 19,
#          'had': 18,
#          'led': 18,
#          '10': 17,
#          '11': 17,
#          'Ø': 17,
#          'also': 16,
#          'II': 16,
#          'be': 16,
#          'into': 16,
#          'I': 15,
#          'modern': 15,
#          'New': 15,
#          '0': 15,
#          '2': 14,
#          'nuclear': 14,
#          'British': 14,
#          'over': 14,
#          'American': 14,
#          'History': 14,
#          'Century': 14,
#          '7': 13,
#          'history': 13,
#          'space': 13,
#          'including': 13,
#          'popular': 13,
#          'most': 13,
#          'million': 13,
#          'between': 13,
#          'China': 13,
#          'years': 12,
#          '1920s': 12,
#          'art': 12,
#          'or': 12,
#          'Germany': 12,
#          'two': 12,
#          '978': 12,
#          'Â': 12,
#          'á': 11,
#          'global': 11,
#          'it': 11,
#          'Press': 11,
#          'Earth': 10,
#          'diseases': 10,
#          '1930s': 10,
#          '1970s': 10,
#          'Population': 10,
#          'billion': 10,
#          'increased': 10,
#          'well': 10,
#          'movement': 10,
#          'its': 10,
#          'military': 10,
#          'wars': 10,
#          'development': 10,
#          'after': 10,
#          'p': 10,
#          'Main': 9,
#          '4': 9,
#          'entertainment': 9,
#          'technology': 9,
#          'December': 9,
#          'It': 9,
#          '1950s': 9,
#          '1980s': 9,
#          'around': 9,
#          'political': 9,
#          'human': 9,
#          'Western': 9,
#          'caused': 9,
#          'their': 9,
#          'Great': 9,
#          'major': 9,
#          'all': 9,
#          'America': 9,
#          'system': 9,
#          'out': 8,
#          'change': 8,
#          '3': 8,
#          '8': 8,
#          'See': 8,
#          '1960s': 8,
#          '1990s': 8,
#          'began': 8,
#          'ended': 8,
#          'warfare': 8,
#          'growth': 8,
#          'Cold': 8,
#          'culture': 8,
#          'saw': 8,
#          'population': 8,
#          'form': 8,
#          'powers': 8,
#          'After': 8,
#          'economic': 8,
#          'communist': 8,
#          'Japan': 8,
#          'East': 8,
#          'only': 8,
#          'use': 8,
#          'half': 8,
#          'both': 8,
#          'life': 8,
#          'being': 8,
#          '18': 8,
#          'against': 8,
#          'throughout': 8,
#          'oil': 8,
#          'original': 8,
#          '21st': 8,
#          'Archived': 8,
#          '2013': 8,
#          '2015': 8,
#          '2023': 8,
#          'more': 7,
#          '5': 7,
#          'Science': 7,
#          'Space': 7,
#          '12': 7,
#          '15': 7,
#          'this': 7,
#          'last': 7,
#          'science': 7,
#          'through': 7,
#          'international': 7,
#          'about': 7,
#          '19th': 7,
#          'Ottoman': 7,
#          'states': 7,
#          'Revolution': 7,
#          'established': 7,
#          'gained': 7,
#          'some': 7,
#          'one': 7,
#          'age': 7,
#          'various': 7,
#          'conflicts': 7,
#          'European': 7,
#          'under': 7,
#          'particularly': 7,
#          'Africa': 7,
#          'This': 7,
#          '19': 7,
#          'deaths': 7,
#          'have': 7,
#          'released': 7,
#          'York': 7,
#          'films': 7,
#          'widely': 7,
#          'film': 7,
#          'James': 7,
#          'System': 7,
#          '2001': 7,
#          '2024': 7,
#          'doi': 7,
#          'University': 7,
#          '05': 7,
#          'Climate': 7,
#          'ed': 7,
#          'television': 6,
#          'games': 6,
#          'environment': 6,
#          'exploration': 6,
#          'Ù': 6,
#          'áƒ': 6,
#          '1940s': 6,
#          '2nd': 6,
#          'forms': 6,
#          'weapons': 6,
#          'power': 6,
#          'automobile': 6,
#          'mass': 6,
#          'home': 6,
#          'video': 6,
#          'made': 6,
#          'energy': 6,
#          'but': 6,
#          'worldwide': 6,
#          'theory': 6,
#          'than': 6,
#          'period': 6,
#          '17': 6,
#          'Italy': 6,
#          'Russian': 6,
#          'state': 6,
#          'been': 6,
#          'Nations': 6,
#          'nations': 6,
#          'disease': 6,
#          'second': 6,
#          'rock': 6,
#          'time': 6,
#          'number': 6,
#          '20': 6,
#          '100': 6,
#          'French': 6,
#          'early': 6,
#          'among': 6,
#          'Arab': 6,
#          'has': 6,
#          'are': 6,
#          'B': 6,
#          'discovered': 6,
#          '2022': 6,
#          '07': 6,
#          '01': 6,
#          'Change': 6,
#          'pp': 6,
#          'February': 6,
#          'politics': 5,
#          'Culture': 5,
#          'architecture': 5,
#          '9': 5,
#          '¾à': 5,
#          'free': 5,
#          '1999': 5,
#          'significant': 5,
#          'Spanish': 5,
#          'spread': 5,
#          'developments': 5,
#          'These': 5,
#          'near': 5,
#          'leading': 5,
#          'engineering': 5,
#          'changed': 5,
#          'nation': 5,
#          'having': 5,
#          'formed': 5,
#          'France': 5,
#          'rapidly': 5,
#          'along': 5,
#          'US': 5,
#          '1945': 5,
#          'Kingdom': 5,
#          'destruction': 5,
#          'latter': 5,
#          'rights': 5,
#          'Eastern': 5,
#          'another': 5,
#          'known': 5,
#          'race': 5,
#          'occurred': 5,
#          'series': 5,
#          'technological': 5,
#          'research': 5,
#          'due': 5,
#          'Most': 5,
#          'independence': 5,
#          'several': 5,
#          '1991': 5,
#          'changes': 5,
#          'late': 5,
#          'much': 5,
#          'civil': 5,
#          'movements': 5,
#          'white': 5,
#          'government': 5,
#          'death': 5,
#          'HIV': 5,
#          'climate': 5,
#          'set': 5,
#          'killed': 5,
#          'estimated': 5,
#          '23': 5,
#          '1918': 5,
#          'control': 5,
#          'Middle': 5,
#          '1921': 5,
#          'fields': 5,
#          '1953': 5,
#          'article': 5,
#          'popularity': 5,
#          'dance': 5,
#          'production': 5,
#          'Modern': 5,
#          'Wright': 5,
#          '1930': 5,
#          'Solar': 5,
#          '48': 5,
#          'cancer': 5,
#          'drugs': 5,
#          'September': 5,
#          'List': 5,
#          '3rd': 5,
#          'retrieved': 5,
#          'November': 5,
#          'J': 5,
#          'IPCC': 5,
#          '2018': 5,
#          'Twentieth': 5,
#          'online': 5,
#          'Wikipedia': 4,
#          'move': 4,
#          'sidebar': 4,
#          'hide': 4,
#          'Toggle': 4,
#          'Video': 4,
#          'Art': 4,
#          '13': 4,
#          'links': 4,
#          '²à': 4,
#          'Õ': 4,
#          '1901': 4,
#          'taken': 4,
#          'William': 4,
#          '1900s': 4,
#          '1910s': 4,
#          '2000': 4,
#          'scientific': 4,
#          'understanding': 4,
#          'communication': 4,
#          'would': 4,
#          'continued': 4,
#          'include': 4,
#          'women': 4,
#          'reduced': 4,
#          'fossil': 4,
#          'fuel': 4,
#          'long': 4,
#          'Meanwhile': 4,
#          'powerful': 4,
#          'chemical': 4,
#          'four': 4,
#          'Britain': 4,
#          'later': 4,
#          'Central': 4,
#          'grew': 4,
#          'culminating': 4,
#          'Asia': 4,
#          'attack': 4,
#          'West': 4,
#          'famine': 4,
#          'divided': 4,
#          'USSR': 4,
#          'produced': 4,
#          'exchange': 4,
#          'Vietnam': 4,
#          'competition': 4,
#          'developing': 4,
#          'influence': 4,
#          'came': 4,
#          'North': 4,
#          'followed': 4,
#          'computers': 4,
#          'air': 4,
#          'expanded': 4,
#          'societies': 4,
#          'By': 4,
#          'often': 4,
#          'Republic': 4,
#          'India': 4,
#          'part': 4,
#          'Indian': 4,
#          'dominant': 4,
#          'violent': 4,
#          'virus': 4,
#          'International': 4,
#          'relations': 4,
#          '1989': 4,
#          'millions': 4,
#          'Hussein': 4,
#          '25': 4,
#          'greatly': 4,
#          'Tulsa': 4,
#          '30': 4,
#          'increase': 4,
#          'June': 4,
#          '1973': 4,
#          'although': 4,
#          'Chinese': 4,
#          '1990': 4,
#          'As': 4,
#          'Computer': 4,
#          'fiction': 4,
#          'genres': 4,
#          'Robert': 4,
#          'John': 4,
#          'game': 4,
#          'held': 4,
#          '1903': 4,
#          '1976': 4,
#          'planets': 4,
#          'launched': 4,
#          'L': 4,
#          '2019': 4,
#          '06': 4,
#          '2004': 4,
#          'eds': 4,
#          'Routledge': 4,
#          'How': 4,
#          '2003': 4,
#          '4th': 4,
#          'ISSNÂ': 4,
#          'May': 4,
#          '2012': 4,
#          'Encyclopedia': 4,
#          '5th': 4,
#          '1st': 4,
#          'account': 3,
#          'Summary': 3,
#          'Wars': 3,
#          'subsection': 3,
#          'Music': 3,
#          'Film': 3,
#          'theatre': 3,
#          'Mathematics': 3,
#          'Medicine': 3,
#          'Notable': 3,
#          'Energy': 3,
#          'Engineering': 3,
#          'Economics': 3,
#          '14': 3,
#          'èªž': 3,
#          'n': 3,
#          'ÑÐ': 3,
#          'ÐµÐ': 3,
#          'ÑÐºÐ': 3,
#          'Î': 3,
#          'æ': 3,
#          'ng': 3,
#          'Wikimedia': 3,
#          'From': 3,
#          'One': 3,
#          'Apollo': 3,
#          'mission': 3,
#          'Millennium': 3,
#          '19thÂ': 3,
#          '20thÂ': 3,
#          '21stÂ': 3,
#          'State': 3,
#          'leaders': 3,
#          'January': 3,
#          '31': 3,
#          '10th': 3,
#          'marked': 3,
#          'unprecedented': 3,
#          'nearly': 3,
#          'started': 3,
#          'geopolitical': 3,
#          'events': 3,
#          'social': 3,
#          'structure': 3,
#          'advances': 3,
#          'advent': 3,
#          'advancement': 3,
#          'transportation': 3,
#          'flight': 3,
#          'extinction': 3,
#          'decolonization': 3,
#          'nationalism': 3,
#          'globalization': 3,
#          'awareness': 3,
#          'environmental': 3,
#          'resources': 3,
#          'impact': 3,
#          'Internet': 3,
#          'eradication': 3,
#          'relativity': 3,
#          'foundational': 3,
#          'forcing': 3,
#          'universe': 3,
#          'believed': 3,
#          'At': 3,
#          '1914': 3,
#          'up': 3,
#          'Russia': 3,
#          'emerged': 3,
#          'addition': 3,
#          'them': 3,
#          'depression': 3,
#          'Hungarian': 3,
#          'post': 3,
#          'Depression': 3,
#          'industrial': 3,
#          'brought': 3,
#          'conflict': 3,
#          'develop': 3,
#          'left': 3,
#          'successor': 3,
#          'League': 3,
#          'forces': 3,
#          'helped': 3,
#          'local': 3,
#          'armed': 3,
#          'resulting': 3,
#          'affected': 3,
#          'With': 3,
#          'communism': 3,
#          'They': 3,
#          'arms': 3,
#          'planet': 3,
#          'scale': 3,
#          'credited': 3,
#          'Korea': 3,
#          'Cuba': 3,
#          'independent': 3,
#          'called': 3,
#          'record': 3,
#          'process': 3,
#          'Hollywood': 3,
#          'industry': 3,
#          'jazz': 3,
#          'pop': 3,
#          'food': 3,
#          'house': 3,
#          'notable': 3,
#          'market': 3,
#          'African': 3,
#          'based': 3,
#          'sex': 3,
#          'South': 3,
#          'seen': 3,
#          'When': 3,
#          'alone': 3,
#          '29': 3,
#          'Flu': 3,
#          '1972': 3,
#          'Economic': 3,
#          'citation': 3,
#          'old': 3,
#          'cultural': 3,
#          '18th': 3,
#          'Americanization': 3,
#          'largest': 3,
#          'still': 3,
#          'fueled': 3,
#          'ethnic': 3,
#          'AIDS': 3,
#          'epidemic': 3,
#          'warming': 3,
#          '1919': 3,
#          'since': 3,
#          '1923': 3,
#          'genocide': 3,
#          '000': 3,
#          'died': 3,
#          'Armenian': 3,
#          'German': 3,
#          '1900': 3,
#          'great': 3,
#          '1916': 3,
#          'Sharif': 3,
#          'Ali': 3,
#          'Henry': 3,
#          'McMahon': 3,
#          'not': 3,
#          '26': 3,
#          '27': 3,
#          'During': 3,
#          '1917': 3,
#          'mid': 3,
#          'members': 3,
#          'black': 3,
#          'rise': 3,
#          'especially': 3,
#          '1936': 3,
#          'when': 3,
#          'Many': 3,
#          'notably': 3,
#          '1948': 3,
#          'Palestine': 3,
#          'Nakba': 3,
#          'methods': 3,
#          'attacks': 3,
#          'where': 3,
#          'Richard': 3,
#          'western': 3,
#          'policy': 3,
#          '1962': 3,
#          'artistic': 3,
#          'City': 3,
#          '1961': 3,
#          '1956': 3,
#          'technologies': 3,
#          'classical': 3,
#          'created': 3,
#          'popularized': 3,
#          'different': 3,
#          'Other': 3,
#          'Pittsburgh': 3,
#          '1905': 3,
#          'allow': 3,
#          'color': 3,
#          'full': 3,
#          'length': 3,
#          'White': 3,
#          'Paul': 3,
#          'Sergei': 3,
#          'D': 3,
#          'theater': 3,
#          'O': 3,
#          'general': 3,
#          'Ailey': 3,
#          'design': 3,
#          'machines': 3,
#          'materials': 3,
#          'invented': 3,
#          'evolution': 3,
#          'determined': 3,
#          'accepted': 3,
#          'probes': 3,
#          'Green': 3,
#          '1950': 3,
#          '47': 3,
#          'Project': 3,
#          '1996': 3,
#          '1947': 3,
#          'blood': 3,
#          'rates': 3,
#          'young': 3,
#          'An': 3,
#          'F': 3,
#          'petroleum': 3,
#          'travel': 3,
#          '1969': 3,
#          'satellites': 3,
#          'Voyager': 3,
#          'related': 3,
#          'Islamic': 3,
#          'Islam': 3,
#          'within': 3,
#          'R': 3,
#          'Ambedkar': 3,
#          '1979': 3,
#          'crisis': 3,
#          '02': 3,
#          'Wolfgang': 3,
#          'PDF': 3,
#          '2011': 3,
#          'July': 3,
#          'G': 3,
#          '2009': 3,
#          '2014': 3,
#          '2021': 3,
#          '2016': 3,
#          'AR5': 3,
#          'WG1': 3,
#          'Historical': 3,
#          '09': 3,
#          'Cambridge': 3,
#          '1998': 3,
#          'Journal': 3,
#          'Society': 3,
#          'b': 3,
#          '2005': 3,
#          '2008': 3,
#          'Working': 3,
#          'Group': 3,
#          'maint': 3,
#          'numeric': 3,
#          'names': 3,
#          'authors': 3,
#          'link': 3,
#          'S': 3,
#          '1915': 3,
#          '7th': 3,
#          'Commons': 3,
#          'centuryâ': 3,
#          '22nd': 3,
#          'unsourced': 3,
#          'menu': 2,
#          'changesUpload': 2,
#          'Search': 2,
#          'Appearance': 2,
#          'Donate': 2,
#          'Create': 2,
#          'Log': 2,
#          'tools': 2,
#          'Nature': 2,
#          'innovation': 2,
#          'Social': 2,
#          'Sport': 2,
#          'Physics': 2,
#          'Astronomy': 2,
#          'Agriculture': 2,
#          'Biology': 2,
#          'Religion': 2,
#          'References': 2,
#          'Sources': 2,
#          'Further': 2,
#          'reading': 2,
#          'External': 2,
#          'languages': 2,
#          'áˆ': 2,
#          'Ã': 2,
#          'å': 2,
#          'ÑƒÑÐºÐ': 2,
#          'Ð³Ð': 2,
#          'Ó': 2,
#          'Ð²Ð': 2,
#          'ÑˆÐ': 2,
#          'Ö': 2,
#          'áƒáƒ': 2,
#          'žá': 2,
#          'ªà': 2,
#          'Ð¹Ð': 2,
#          'ƒá': 2,
#          'ReadEditView': 2,
#          'Tools': 2,
#          'General': 2,
#          'What': 2,
#          'export': 2,
#          'For': 2,
#          'see': 2,
#          '24': 2,
#          '1968': 2,
#          'astronaut': 2,
#          'photograph': 2,
#          'orbit': 2,
#          'millennium': 2,
#          'Timelines': 2,
#          'Categories': 2,
#          'models': 2,
#          'dominated': 2,
#          'pandemic': 2,
#          'defined': 2,
#          'era': 2,
#          'digital': 2,
#          'computing': 2,
#          'continuing': 2,
#          'sixth': 2,
#          'efforts': 2,
#          'Cultural': 2,
#          'communications': 2,
#          'what': 2,
#          'economy': 2,
#          'Poverty': 2,
#          'rising': 2,
#          'living': 2,
#          'appliances': 2,
#          'common': 2,
#          'recording': 2,
#          'concern': 2,
#          'pollution': 2,
#          'term': 2,
#          'Moon': 2,
#          'allowed': 2,
#          'medical': 2,
#          'resulted': 2,
#          'infectious': 2,
#          'Scientific': 2,
#          'quantum': 2,
#          'physics': 2,
#          'scientists': 2,
#          'beginning': 2,
#          'past': 2,
#          'empires': 2,
#          'First': 2,
#          'inventions': 2,
#          'dead': 2,
#          'Triple': 2,
#          'Entente': 2,
#          'replaced': 2,
#          'victorious': 2,
#          'Powers': 2,
#          'Bulgaria': 2,
#          'particular': 2,
#          'Austro': 2,
#          'Tsarist': 2,
#          'Bolsheviks': 2,
#          'then': 2,
#          'Fascism': 2,
#          'Spain': 2,
#          'Nazi': 2,
#          'expansion': 2,
#          'transformed': 2,
#          'advanced': 2,
#          'Axis': 2,
#          'dramatic': 2,
#          'success': 2,
#          'defeated': 2,
#          'Canada': 2,
#          'Allies': 2,
#          'invasion': 2,
#          'atomic': 2,
#          'total': 2,
#          '60': 2,
#          'August': 2,
#          'Hiroshima': 2,
#          'assured': 2,
#          'could': 2,
#          'issues': 2,
#          'aid': 2,
#          'rest': 2,
#          'Plan': 2,
#          'allies': 2,
#          'soon': 2,
#          'competing': 2,
#          'capitalism': 2,
#          'Berlin': 2,
#          'decades': 2,
#          'sides': 2,
#          'large': 2,
#          'historians': 2,
#          'strike': 2,
#          'directly': 2,
#          'proxy': 2,
#          'worldâ': 2,
#          'while': 2,
#          'substantial': 2,
#          'community': 2,
#          'significantly': 2,
#          'wave': 2,
#          'together': 2,
#          'strong': 2,
#          'presence': 2,
#          'picture': 2,
#          'Broadway': 2,
#          'hip': 2,
#          'hop': 2,
#          'style': 2,
#          'collapsed': 2,
#          'internal': 2,
#          'governments': 2,
#          'difficult': 2,
#          'economies': 2,
#          'industrialization': 2,
#          'trade': 2,
#          'nature': 2,
#          'mechanical': 2,
#          'radio': 2,
#          'broadcasting': 2,
#          'conditioning': 2,
#          'antibiotics': 2,
#          'quality': 2,
#          'massively': 2,
#          'Martin': 2,
#          'Washington': 2,
#          '1963': 2,
#          'non': 2,
#          'parts': 2,
#          'backed': 2,
#          'action': 2,
#          'Attitudes': 2,
#          'sexual': 2,
#          'like': 2,
#          'bare': 2,
#          'society': 2,
#          'Harrison': 2,
#          'altered': 2,
#          'needed': 2,
#          'subcontinent': 2,
#          'centuries': 2,
#          'finally': 2,
#          'complete': 2,
#          'order': 2,
#          'colonialism': 2,
#          'undergoing': 2,
#          'position': 2,
#          'populations': 2,
#          'causes': 2,
#          'done': 2,
#          'consider': 2,
#          'serious': 2,
#          '16': 2,
#          'occurring': 2,
#          'carbon': 2,
#          'dioxide': 2,
#          'fuels': 2,
#          'emissions': 2,
#          'articles': 2,
#          'Diplomatic': 2,
#          '1939': 2,
#          'Map': 2,
#          'territorial': 2,
#          'hundreds': 2,
#          '50': 2,
#          'Political': 2,
#          'those': 2,
#          'battles': 2,
#          'civilians': 2,
#          'killings': 2,
#          'Charles': 2,
#          'Tilly': 2,
#          'result': 2,
#          'units': 2,
#          'course': 2,
#          '21': 2,
#          'approximately': 2,
#          'violence': 2,
#          '22': 2,
#          'increasing': 2,
#          'Arabs': 2,
#          'who': 2,
#          'fighting': 2,
#          'collapse': 2,
#          'birth': 2,
#          'techniques': 2,
#          'included': 2,
#          'introduction': 2,
#          'widespread': 2,
#          'transition': 2,
#          'inspired': 2,
#          'Osage': 2,
#          '1931': 2,
#          'Nation': 2,
#          '28': 2,
#          'Race': 2,
#          'Oklahoma': 2,
#          'perpetrated': 2,
#          'Second': 2,
#          'testing': 2,
#          'Jewish': 2,
#          'Palestinians': 2,
#          'influenced': 2,
#          'according': 2,
#          'campaign': 2,
#          'Indochina': 2,
#          'parties': 2,
#          'involved': 2,
#          '1950â': 2,
#          '1975': 2,
#          'further': 2,
#          'areas': 2,
#          'Muhammad': 2,
#          '1912': 2,
#          'People': 2,
#          '1949': 2,
#          'Asian': 2,
#          'Kong': 2,
#          '1997': 2,
#          'Four': 2,
#          'leads': 2,
#          'tens': 2,
#          '1959': 2,
#          '36': 2,
#          'Afghanistan': 2,
#          'contributed': 2,
#          'Tiananmen': 2,
#          'Square': 2,
#          'protests': 2,
#          'thousands': 2,
#          'year': 2,
#          'literature': 2,
#          '1911': 2,
#          'capital': 2,
#          'writers': 2,
#          'composers': 2,
#          'artists': 2,
#          'become': 2,
#          'media': 2,
#          'fashion': 2,
#          'Elizabeth': 2,
#          'iconic': 2,
#          'figure': 2,
#          ...})

# %%
countr = pd.read_csv("adj_countries_list_20th_century_1.5.csv", index_col = 0)

# %%
countr.head()
# Out:
#     country_name  Unnamed: 2
# 1   Afghanistan          NaN
# 2       Albania          NaN
# 3       Algeria          NaN
# 4       Andorra          NaN
# 5        Angola          NaN

# %%
countr['country_name'] = countr['country_name'].str.strip()

# %%
#countr.drop(columns = ['Unnamed:2'], axis=1, inplace=True)

# %%
#Replace names with aliases

# %%
#countr['country_name'] = countr['country_name'].replace('Bahamas, The','Bahamas')

#countr['country_name'] = countr['country_name'].replace('Bosnia and Herzegovina','Bosnia')

#countr['country_name'] = countr['country_name'].replace('Central African Republic','CAR')
#countr['country_name'] = countr['country_name'].replace("China, People's Republic of","China")
#countr['country_name'] = countr['country_name'].replace('Congo, Democratic Republic of the','DRC')
#countr['country_name'] = countr['country_name'].replace('Congo, Republic of the','Congo')
#countr['country_name'] = countr['country_name'].replace('Czech Republic','Czechia')

#countr['country_name'] = countr['country_name'].replace('Dominican Republic','DR')

#countr['country_name'] = countr['country_name'].replace('Equatorial Guinea','Guinea')

#countr['country_name'] = countr['country_name'].replace('Gambia, The','Gambia')

#countr['country_name'] = countr['country_name'].replace('Korea, North', 'North Korea')
#countr['country_name'] = countr['country_name'].replace('Korea, South','South Korea')

#countr['country_name'] = countr['country_name'].replace('Micronesia, Federated States of','Micronesia')

#countr['country_name'] = countr['country_name'].replace('United Arab Emirates','UAE')
#countr['country_name'] = countr['country_name'].replace('United Kingdom','UK')
#countr['country_name'] = countr['country_name'].replace('United States','US')
#countr['country_name'] = countr['country_name'].replace('Vatican City (Holy See)','Vatican_City')

#countr['country_name'] = countr['country_name'].replace("Donetsk People's Republic","DPR")
#countr['country_name'] = countr['country_name'].replace("Luhansk People's Republic","LPR")

#countr['country_name'] = countr['country_name'].replace('Sahrawi Arab Democratic Republic','Sahrawi Republic')

# %%
#Remove country names that begin with "The"

# %%
#countr['country_alias'] = countr['country_name'].apply(lambda x: x.rsplit(' ',1)[-1])

# %%
countr_list = countr['country_name'].to_list()

# %%
dict_of_counts = {d : all_counts[d] for d in countr_list}

# %%
dict_of_counts
# Out:
# {'Afghanistan': 2,
#  'Albania': 0,
#  'Algeria': 0,
#  'Andorra': 0,
#  'Angola': 0,
#  'Antigua and Barbuda': 0,
#  'Argentina': 1,
#  'Armenia': 0,
#  'Australia': 2,
#  'Austria': 1,
#  'Azerbaijan': 0,
#  'Bahamas, The': 0,
#  'Bahrain': 0,
#  'Bangladesh': 0,
#  'Barbados': 0,
#  'Belarus': 0,
#  'Belgium': 0,
#  'Belize': 0,
#  'Benin': 0,
#  'Bhutan': 0,
#  'Bolivia': 0,
#  'Bosnia and Herzegovina': 0,
#  'Botswana': 0,
#  'Brazil': 0,
#  'Brunei': 0,
#  'Bulgaria': 2,
#  'Burkina Faso': 0,
#  'Burundi': 0,
#  'Cambodia': 0,
#  'Cameroon': 0,
#  'Canada': 2,
#  'Cape Verde': 0,
#  'Central African Republic': 0,
#  'Chad': 0,
#  'Chile': 0,
#  "China, People's Republic of": 0,
#  'Colombia': 0,
#  'Comoros': 0,
#  'Congo, Democratic Republic of the': 0,
#  'Congo, Republic of the': 0,
#  'Costa Rica': 0,
#  'Croatia': 0,
#  'Cuba': 3,
#  'Cyprus': 0,
#  'Czech Republic': 0,
#  'Denmark': 0,
#  'Djibouti': 0,
#  'Dominica': 0,
#  'Dominican Republic': 0,
#  'East Timor': 0,
#  'Ecuador': 0,
#  'Egypt': 1,
#  'El Salvador': 0,
#  'Equatorial Guinea': 0,
#  'Eritrea': 0,
#  'Estonia': 0,
#  'Eswatini': 0,
#  'Ethiopia': 0,
#  'Fiji': 0,
#  'Finland': 0,
#  'France': 5,
#  'Gabon': 0,
#  'Gambia, The': 0,
#  'Georgia': 0,
#  'Germany': 12,
#  'Ghana': 0,
#  'Greece': 0,
#  'Grenada': 0,
#  'Guatemala': 0,
#  'Guinea': 0,
#  'Bissau': 0,
#  'Guyana': 0,
#  'Haiti': 0,
#  'Honduras': 0,
#  'Hungary': 1,
#  'Iceland': 0,
#  'India': 4,
#  'Indonesia': 0,
#  'Iran': 1,
#  'Iraq': 0,
#  'Ireland': 1,
#  'Israel': 1,
#  'Italy': 6,
#  'Ivory Coast': 0,
#  'Jamaica': 0,
#  'Japan': 8,
#  'Jordan': 0,
#  'Kazakhstan': 0,
#  'Kenya': 0,
#  'Kiribati': 0,
#  'Korea, North': 0,
#  'Korea, South': 0,
#  'Kuwait': 0,
#  'Kyrgyzstan': 0,
#  'Laos': 0,
#  'Latvia': 0,
#  'Lebanon': 0,
#  'Lesotho': 0,
#  'Liberia': 0,
#  'Libya': 0,
#  'Liechtenstein': 0,
#  'Lithuania': 0,
#  'Luxembourg': 0,
#  'Madagascar': 0,
#  'Malawi': 0,
#  'Malaysia': 0,
#  'Maldives': 0,
#  'Mali': 0,
#  'Malta': 0,
#  'Marshall Islands': 0,
#  'Mauritania': 0,
#  'Mauritius': 0,
#  'Mexico': 0,
#  'Micronesia, Federated States of': 0,
#  'Moldova': 0,
#  'Monaco': 0,
#  'Mongolia': 0,
#  'Montenegro': 1,
#  'Morocco': 0,
#  'Mozambique': 0,
#  'Myanmar': 0,
#  'Namibia': 0,
#  'Nauru': 0,
#  'Nepal': 0,
#  'Netherlands': 0,
#  'New Zealand': 0,
#  'Nicaragua': 0,
#  'Niger': 0,
#  'Nigeria': 0,
#  'North Macedonia': 0,
#  'Norway': 0,
#  'Oman': 0,
#  'Pakistan': 1,
#  'Palau': 0,
#  'Palestine': 3,
#  'Panama': 0,
#  'Papua New Guinea': 0,
#  'Paraguay': 0,
#  'Peru': 0,
#  'Philippines': 0,
#  'Poland': 1,
#  'Portugal': 0,
#  'Qatar': 0,
#  'Romania': 1,
#  'Russia': 3,
#  'Rwanda': 0,
#  'Saint Kitts and Nevis': 0,
#  'Saint Lucia': 0,
#  'Saint Vincent and the Grenadines': 0,
#  'Samoa': 0,
#  'San Marino': 0,
#  'Sao and Principe': 0,
#  'Saudi Arabia': 0,
#  'Senegal': 0,
#  'Serbia': 0,
#  'Seychelles': 0,
#  'Sierra Leone': 0,
#  'Singapore': 0,
#  'Slovakia': 0,
#  'Slovenia': 0,
#  'Solomon Islands': 0,
#  'Somalia': 0,
#  'South Africa': 0,
#  'South Sudan': 0,
#  'Spain': 2,
#  'Sri Lanka': 0,
#  'Sudan': 0,
#  'Suriname': 0,
#  'Sweden': 0,
#  'Switzerland': 0,
#  'Syria': 0,
#  'Tajikistan': 0,
#  'Tanzania': 0,
#  'Thailand': 0,
#  'Togo': 0,
#  'Tonga': 0,
#  'Trinidad and Tobago': 0,
#  'Tunisia': 0,
#  'Turkey': 0,
#  'Turkmenistan': 0,
#  'Tuvalu': 0,
#  'Uganda': 0,
#  'Ukraine': 0,
#  'United Arab Emirates': 0,
#  'United Kingdom': 0,
#  'United States': 0,
#  'Uruguay': 0,
#  'Uzbekistan': 0,
#  'Vanuatu': 0,
#  'Vatican City (Holy See)': 0,
#  'Venezuela': 0,
#  'Vietnam': 4,
#  'Yemen': 0,
#  'Zambia': 0,
#  'Zimbabwe': 0,
#  'Abkhazia': 0,
#  'Artsakh': 0,
#  'Cook Islands': 0,
#  "Donetsk People's Republic": 0,
#  'Kosovo': 0,
#  "Luhansk People's Republic": 0,
#  'Niue': 0,
#  'Northern Cyprus': 0,
#  'Sahrawi Arab Democratic Republic': 0,
#  'Somaliland': 0,
#  'South Ossetia': 0,
#  'Taiwan': 0,
#  'Transnistria': 0}

# %%
#Search for the names from the list in the dictionary

dct = {v:[k] for v,k in dict_of_counts.items()}
df = pd.DataFrame(dct)

# %%
df
# Out:
#    Afghanistan  Albania  Algeria  Andorra  Angola  Antigua and Barbuda  \
# 0            2        0        0        0       0                    0
#
#    Argentina  Armenia  Australia  Austria  ...  Donetsk People's Republic  \
# 0          1        0          2        1  ...                          0
#
#    Kosovo  Luhansk People's Republic  Niue  Northern Cyprus  \
# 0       0                          0     0                0
#
#    Sahrawi Arab Democratic Republic  Somaliland  South Ossetia  Taiwan  \
# 0                                 0           0              0       0
#
#    Transnistria
# 0             0
#
# [1 rows x 208 columns]

# %%
df = df.transpose().reset_index()

# %%
df.dtypes
# Out:
# index    object
# 0         int64
# dtype: object

# %%
df
# Out:
#                                 index  0
# 0                         Afghanistan  2
# 1                             Albania  0
# 2                             Algeria  0
# 3                             Andorra  0
# 4                              Angola  0
# ..                                ... ..
# 203  Sahrawi Arab Democratic Republic  0
# 204                        Somaliland  0
# 205                     South Ossetia  0
# 206                            Taiwan  0
# 207                      Transnistria  0
#
# [208 rows x 2 columns]

# %%
df.rename(columns = {"index":"country_name", 0:"Times mentioned"}, inplace = True)

# %%
df
# Out:
#                          country_name  Times mentioned
# 0                         Afghanistan                2
# 1                             Albania                0
# 2                             Algeria                0
# 3                             Andorra                0
# 4                              Angola                0
# ..                                ...              ...
# 203  Sahrawi Arab Democratic Republic                0
# 204                        Somaliland                0
# 205                     South Ossetia                0
# 206                            Taiwan                0
# 207                      Transnistria                0
#
# [208 rows x 2 columns]

# %%
df.shape
# Out:
# (208, 2)

# %% [markdown]
# ### 11.) Create a plot showing the frequency of the number of times these countries are mentioned in the text. Is there anything in
# ###    particular you notice in this plot? Describe your findings in a Markdown cell underneath the plot.

# %% [markdown]
# #### Find top 15 countries which have the most number of times that these countries are mentioned in the text

# %%
df.sort_values("Times mentioned", ascending = False)
# Out:
#      country_name  Times mentioned
# 64        Germany               12
# 85          Japan                8
# 82          Italy                6
# 60         France                5
# 191       Vietnam                4
# ..            ...              ...
# 77      Indonesia                0
# 79           Iraq                0
# 83    Ivory Coast                0
# 84        Jamaica                0
# 207  Transnistria                0
#
# [208 rows x 2 columns]

# %%
top15 = df.nlargest(15, "Times mentioned")

# %%
top15
# Out:
#     country_name  Times mentioned
# 64       Germany               12
# 85         Japan                8
# 82         Italy                6
# 60        France                5
# 76         India                4
# 191      Vietnam                4
# 42          Cuba                3
# 134    Palestine                3
# 144       Russia                3
# 0    Afghanistan                2
# 8      Australia                2
# 25      Bulgaria                2
# 30        Canada                2
# 164        Spain                2
# 6      Argentina                1

# %%
plt.figure(figsize=(10, 5))
with sns.dark_palette("#79C", 15):
    sns.barplot(x = "Times mentioned", y = "country_name",
    saturation=0.9, data = top15).set_title("Key Events of 20th Century - most frequently mentioned countries")

# %% [markdown]
# Germany was mentioned 50% more than the next highly-mentioned country - Japan.
